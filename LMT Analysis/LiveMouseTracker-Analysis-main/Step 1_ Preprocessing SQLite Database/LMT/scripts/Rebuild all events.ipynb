# %% [markdown]
# # Rebuild All Events
#     This script builds/rebuilds all the events of Live Mouse Tracker
#     You can also create your own events and add them to this process
#
#     Approximate time is 1h of computation for a 24h database of 4 animals

# %% [markdown]
# # Parameters:
#     This will compute automatically events for your database, and adjust settings for you.
#
#     If you remove the automatic settings, you can force parameters:
#         Set minT and maxT to process the database.
#         Set windowT to divide the computation load in segment of that duration. Default value is 1 day.

# %%
import sys
sys.path.insert(1, "../")
from lmtanalysis.Measure import *

# set this to false if you want to set manual parameters.
automaticSettings = True

# Manual parameters:

''' minT and maxT to process the analysis (expressed in frame) '''
minT = 0
maxT = 3*oneDay
''' time window to compute the events (in frame). '''
windowT = 1*oneDay
''' speed up process '''
USE_CACHE_LOAD_DETECTION_CACHE = True

# %% [markdown]
# # Run this section to compute your database
#     You will be prompt to provide a database

# %%
''' Created on 26 march 2019 @author: Fab '''

import sys
sys.path.insert(1, "../")
import sqlite3
from lmtanalysis.Animal import *
import matplotlib.pyplot as plt
from lmtanalysis.Event import *
from lmtanalysis.Measure import *
from lmtanalysis import BuildEventTrain3, BuildEventTrain4, BuildEventTrain2, BuildEventFollowZone, BuildEventRear5, BuildEventFloorSniffing,\
    BuildEventSocialApproach, BuildEventSocialEscape, BuildEventApproachContact,BuildEventOralOralContact, BuildEventHuddling, \
    BuildEventApproachRear, BuildEventGroup2, BuildEventGroup3, BuildEventGroup4, BuildEventOralGenitalContact, \
    BuildEventStop, BuildEventNovObj_Interaction, \
    BuildEventMove, BuildEventGroup3MakeBreak, BuildEventGroup4MakeBreak,\
    BuildEventSideBySide, BuildEventSideBySideOpposite, BuildEventDetection,\
    BuildDataBaseIndex, BuildEventWallJump, BuildEventSAP,\
    BuildEventOralSideSequence, CheckWrongAnimal,\
    CorrectDetectionIntegrity, BuildEventNest4, BuildEventNest3, BuildEventGetAway
    
from psutil import virtual_memory

from tkinter.filedialog import askopenfilename
from lmtanalysis.TaskLogger import TaskLogger
import sys
import traceback
from lmtanalysis.FileUtil import getFilesToProcess
from lmtanalysis.EventTimeLineCache import flushEventTimeLineCache,\
    disableEventTimeLineCache


from lmtanalysis.EventTimeLineCache import EventTimeLineCached

def getNumberOfFrames(file):
    
    connection = sqlite3.connect( file )
    c = connection.cursor() 
    query = "SELECT MAX(FRAMENUMBER) FROM FRAME";
    c.execute( query )
    result = c.fetchall()
    numberOfFrames = int( result[0][0] )
    connection.close()
    
    return numberOfFrames

class FileProcessException(Exception):
    pass

eventClassList = [                  
                  BuildEventOralOralContact,
                  BuildEventOralGenitalContact,
                  BuildEventSideBySide,
                  BuildEventSideBySideOpposite,
                  BuildEventTrain2,                  
                  BuildEventTrain3,
                  BuildEventTrain4,
                  BuildEventMove,
                  BuildEventFollowZone,
                  BuildEventRear5,
                  BuildEventSocialApproach,
                  BuildEventGetAway,
                  BuildEventSocialEscape,
                  BuildEventApproachRear,
                  BuildEventGroup2,
                  BuildEventGroup3,
                  BuildEventGroup4,
                  BuildEventGroup3MakeBreak,
                  BuildEventGroup4MakeBreak,
                  BuildEventHuddling,
                  BuildEventStop,
                  BuildEventNovObj_Interaction,
                  BuildEventApproachContact,
                  BuildEventWallJump,
                  BuildEventSAP,
                  BuildEventOralSideSequence,
                  BuildEventNest3,
                  BuildEventNest4
                   ]

def flushEvents( connection ):
    
    print("Flushing events...")

    for ev in eventClassList:
        
        chrono = Chronometer( "Flushing event " + str(ev) )
        ev.flush( connection );      
        chrono.printTimeInS()
    

def processTimeWindow( connection, currentMinT , currentMaxT ):
    
    CheckWrongAnimal.check( connection, tmin=currentMinT, tmax=currentMaxT )
    
    # Warning: enabling this process (CorrectDetectionIntegrity) will alter the database permanently
    #CorrectDetectionIntegrity.correct( connection, tmin=0, tmax=maxT )
                            
    BuildEventDetection.reBuildEvent( connection, file, tmin=currentMinT, tmax=currentMaxT )

    animalPool = None
    
    flushEventTimeLineCache()
    
    if ( USE_CACHE_LOAD_DETECTION_CACHE ):
        print("Caching load of animal detection...")
        animalPool = AnimalPool( )
        animalPool.loadAnimals( connection )
        animalPool.loadDetection( start = currentMinT, end = currentMaxT )
        print("Caching load of animal detection done.")

    for ev in eventClassList:
        
        chrono = Chronometer( str( ev ) )
        ev.reBuildEvent( connection, file, tmin=currentMinT, tmax=currentMaxT, pool = animalPool )        
        chrono.printTimeInS()

def process( file ):

    print(file)
    
    if automaticSettings:
        print("Automatic settings.")
        windowT = 1*oneDay
        minT = 0
        maxT = getNumberOfFrames( file )
        print ( "Auto max set to" , maxT , "frames")
        
    
    chronoFullFile = Chronometer("File " + file )
    
    connection = sqlite3.connect( file )
    
    # update missing fields
    try:
        connection = sqlite3.connect( file )    
        c = connection.cursor()            
        query = "ALTER TABLE EVENT ADD METADATA TEXT";
        c.execute( query )    
        connection.commit()
        c.close()
        connection.close()
    except:
        print( "METADATA field already exists" , file )
        
    #build index
    
    BuildDataBaseIndex.buildDataBaseIndex( connection, force=False )
        
    '''
    # build sensor data    
    animalPool = AnimalPool( )
    animalPool.loadAnimals( connection )
    animalPool.buildSensorData(file)
    '''
    
    currentT = minT

    try:

        flushEvents( connection )
        
        while currentT < maxT:
                        
            currentMinT = currentT
            currentMaxT = currentT+ windowT
            if ( currentMaxT > maxT ):
                currentMaxT = maxT
                
            chronoTimeWindowFile = Chronometer("File "+ file+ " currentMinT: "+ str(currentMinT)+ " currentMaxT: " + str(currentMaxT) );
            processTimeWindow( connection, currentMinT, currentMaxT )    
            chronoTimeWindowFile.printTimeInS()
            
            currentT += windowT

                        

        print("Full file process time: ")
        chronoFullFile.printTimeInS()
        
        TEST_WINDOWING_COMPUTATION = False
        
        if ( TEST_WINDOWING_COMPUTATION ):
                
            print("*************")
            print("************* TEST START SECTION")
            print("************* Test if results are the same with or without the windowing.")
            
            # display and record to a file all events found, checking with rolling idA from None to 4. Save nbEvent and total len
            
            eventTimeLineList = []
            
            eventList = getAllEvents( connection )
            file = open("outEvent"+str(windowT)+".txt","w")  
            file.write( "Event name\nnb event\ntotal duration" )
            
            for eventName in eventList:
                for idAnimalA in range( 0,5 ):                
                        idA = idAnimalA 
                        if idA == 0:
                            idA = None
                        timeLine = EventTimeLineCached( connection, file, eventName, idA,  minFrame=minT, maxFrame=maxT )
                        eventTimeLineList.append( timeLine )
                        file.write( timeLine.eventNameWithId+"\t"+str(len(timeLine.eventList))+"\t"+str(timeLine.getTotalLength())+"\n" )            
            
            file.close() 
    
            #plotMultipleTimeLine( eventTimeLineList )
            
            print("************* END TEST")
        
        
    except:
        
        exc_type, exc_value, exc_traceback = sys.exc_info()
        lines = traceback.format_exception(exc_type, exc_value, exc_traceback)
        error = ''.join('!! ' + line for line in lines)
        
        t = TaskLogger( connection )
        t.addLog( error )
        
        print( error, file=sys.stderr ) 
        
        raise FileProcessException()
            
def getAllEvents( connection ):
    
    query = "select name from event group by name order by name"
    c = connection.cursor()     
    c.execute( query )    
    all_rows = c.fetchall()        
    header = [ "Name" ]
    data =[]    
    for row in all_rows:
        data.append( row[0] )
    return data        

print("Code launched.")

mem = virtual_memory()
availableMemoryGB = mem.total / 1000000000
print( "Total memory on computer: (GB)", availableMemoryGB ) 

if availableMemoryGB < 10:
    print( "Not enough memory to use cache load of events.")
    disableEventTimeLineCache()

print("A window is popping (maybe hidden) asking for files to process...")
files = getFilesToProcess()

chronoFullBatch = Chronometer("Full batch" )    

if ( files != None ):

    for file in files:
        try:
            print ( "Processing file" , file )
            process( file )
        except FileProcessException:
            print ( "STOP PROCESSING FILE " + file , file=sys.stderr  )

        flushEventTimeLineCache()

chronoFullBatch.printTimeInS()
print( "*** ALL JOBS DONE ***")
# Out:
# Code launched.
# Total memory on computer: (GB) 16.984559616
# A window is popping (maybe hidden) asking for files to process...
# Processing file C:/Users/amyrh/Documents/AA_Neuroscience_MSc/AA_Project/Live Mouse Tracker/Processing Data/Project11_CorrectDetectionIdentityGraphs/Novel Object/19666-01-03-05_06-02-2020_Obj_Rebuilt_Uncorrected.sqlite
# C:/Users/amyrh/Documents/AA_Neuroscience_MSc/AA_Project/Live Mouse Tracker/Processing Data/Project11_CorrectDetectionIdentityGraphs/Novel Object/19666-01-03-05_06-02-2020_Obj_Rebuilt_Uncorrected.sqlite
# Automatic settings.
# Auto max set to 332427 frames
# METADATA field already exists C:/Users/amyrh/Documents/AA_Neuroscience_MSc/AA_Project/Live Mouse Tracker/Processing Data/Project11_CorrectDetectionIdentityGraphs/Novel Object/19666-01-03-05_06-02-2020_Obj_Rebuilt_Uncorrected.sqlite
# Creating lmtanalysis indexes...
# CREATE INDEX `animalIndex` ON `ANIMAL` (`ID` );
# index animalIndex already exists
# CREATE INDEX `detectionIndex` ON `DETECTION` (`ID` ASC,`FRAMENUMBER` ASC);
# index detectionIndex already exists
# CREATE INDEX `detetIdIndex` ON `DETECTION` (`ID` ASC);
# index detetIdIndex already exists
# CREATE INDEX `detframenumberIndex` ON `DETECTION` (`FRAMENUMBER` ASC);
# index detframenumberIndex already exists
# CREATE INDEX `eventEndFrameIndex` ON `EVENT` (`ENDFRAME` ASC);
# index eventEndFrameIndex already exists
# CREATE INDEX `eventIndex` ON `EVENT` (`ID` ASC,`STARTFRAME` ASC,`ENDFRAME` ASC);
# index eventIndex already exists
# CREATE INDEX `eventStartFrameIndex` ON `EVENT` (`STARTFRAME` ASC);
# index eventStartFrameIndex already exists
# CREATE INDEX `eventstartendIndex` ON `EVENT` (`STARTFRAME` ASC,`ENDFRAME` ASC);
# index eventstartendIndex already exists
# CREATE INDEX `indexeventidIndex` ON `EVENT` (`ID` ASC);
# index indexeventidIndex already exists
# CREATE INDEX 'detectionFastLoadXYIndex' ON 'DETECTION' ('ANIMALID' ,'FRAMENUMBER' ASC,'MASS_X' ,'MASS_Y' );
# index detectionFastLoadXYIndex already exists
# Log table does not exists, creating Log table
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build DataBase Index','0','2020-03-26 16:13:13','0','-1' );
# Flushing events...
# Deleting event Oral-oral Contact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Oral-oral Contact"
# Number of event deleted: 13366
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventOralOralContact' from '..\\lmtanalysis\\BuildEventOralOralContact.py'>  ]  1.0495505332946777  seconds
# Deleting event Oral-genital Contact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Oral-genital Contact"
# Number of event deleted: 13977
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventOralGenitalContact' from '..\\lmtanalysis\\BuildEventOralGenitalContact.py'>  ]  0.8790593147277832  seconds
# Deleting event Side by side Contact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Side by side Contact"
# Number of event deleted: 7546
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventSideBySide' from '..\\lmtanalysis\\BuildEventSideBySide.py'>  ]  0.5425493717193604  seconds
# Deleting event Side by side Contact, opposite way (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Side by side Contact, opposite way"
# Number of event deleted: 12
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventSideBySideOpposite' from '..\\lmtanalysis\\BuildEventSideBySideOpposite.py'>  ]  0.09834527969360352  seconds
# Deleting event Train2 (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Train2"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventTrain2' from '..\\lmtanalysis\\BuildEventTrain2.py'>  ]  0.08731293678283691  seconds
# Deleting event Train3 (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Train3"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventTrain3' from '..\\lmtanalysis\\BuildEventTrain3.py'>  ]  0.09672904014587402  seconds
# Deleting event Train4 (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Train4"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventTrain4' from '..\\lmtanalysis\\BuildEventTrain4.py'>  ]  0.10074138641357422  seconds
# Deleting event Move (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Move"
# Number of event deleted: 0
# Deleting event Move isolated (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Move isolated"
# Number of event deleted: 0
# Deleting event Move in contact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Move in contact"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventMove' from '..\\lmtanalysis\\BuildEventMove.py'>  ]  0.29707980155944824  seconds
# Deleting event FollowZone Isolated (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="FollowZone Isolated"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventFollowZone' from '..\\lmtanalysis\\BuildEventFollowZone.py'>  ]  0.1067192554473877  seconds
# Deleting event Rear isolated (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Rear isolated"
# Number of event deleted: 0
# Deleting event Rear in contact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Rear in contact"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventRear5' from '..\\lmtanalysis\\BuildEventRear5.py'>  ]  0.20248818397521973  seconds
# Deleting event Social approach (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Social approach"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventSocialApproach' from '..\\lmtanalysis\\BuildEventSocialApproach.py'>  ]  0.08873152732849121  seconds
# Deleting event Get away (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Get away"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventGetAway' from '..\\lmtanalysis\\BuildEventGetAway.py'>  ]  0.0777895450592041  seconds
# Deleting event Social escape (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Social escape"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventSocialEscape' from '..\\lmtanalysis\\BuildEventSocialEscape.py'>  ]  0.08776521682739258  seconds
# Deleting event Approach rear (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Approach rear"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventApproachRear' from '..\\lmtanalysis\\BuildEventApproachRear.py'>  ]  0.07679486274719238  seconds
# Deleting event Group2 (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Group2"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventGroup2' from '..\\lmtanalysis\\BuildEventGroup2.py'>  ]  0.07879090309143066  seconds
# Deleting event Group3 (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Group3"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventGroup3' from '..\\lmtanalysis\\BuildEventGroup3.py'>  ]  0.0997321605682373  seconds
# Deleting event Group4 (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Group4"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventGroup4' from '..\\lmtanalysis\\BuildEventGroup4.py'>  ]  0.0843505859375  seconds
# Deleting event Group 3 make (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Group 3 make"
# Number of event deleted: 0
# Deleting event Group 3 break (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Group 3 break"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventGroup3MakeBreak' from '..\\lmtanalysis\\BuildEventGroup3MakeBreak.py'>  ]  0.15558290481567383  seconds
# Deleting event Group 4 make (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Group 4 make"
# Number of event deleted: 0
# Deleting event Group 4 break (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Group 4 break"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventGroup4MakeBreak' from '..\\lmtanalysis\\BuildEventGroup4MakeBreak.py'>  ]  0.1595780849456787  seconds
# Deleting event Huddling (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Huddling"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventHuddling' from '..\\lmtanalysis\\BuildEventHuddling.py'>  ]  0.09474563598632812  seconds
# Deleting event Stop in contact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Stop in contact"
# Number of event deleted: 0
# Deleting event Stop isolated (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Stop isolated"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventStop' from '..\\lmtanalysis\\BuildEventStop.py'>  ]  0.17801189422607422  seconds
# Deleting event NovObj Zone (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="NovObj Zone"
# Number of event deleted: 0
# Deleting event NovObj Stop (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="NovObj Stop"
# Number of event deleted: 0
# Deleting event NovObj Interact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="NovObj Interact"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventNovObj_Interaction' from '..\\lmtanalysis\\BuildEventNovObj_Interaction.py'>  ]  0.2503819465637207  seconds
# Deleting event Approach contact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Approach contact"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventApproachContact' from '..\\lmtanalysis\\BuildEventApproachContact.py'>  ]  0.08777451515197754  seconds
# Deleting event WallJump (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="WallJump"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventWallJump' from '..\\lmtanalysis\\BuildEventWallJump.py'>  ]  0.07779121398925781  seconds
# Deleting event SAP (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="SAP"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventSAP' from '..\\lmtanalysis\\BuildEventSAP.py'>  ]  0.0827784538269043  seconds
# Deleting event seq oral oral - oral genital (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="seq oral oral - oral genital"
# Number of event deleted: 0
# Deleting event seq oral geni - oral oral (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="seq oral geni - oral oral"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventOralSideSequence' from '..\\lmtanalysis\\BuildEventOralSideSequence.py'>  ]  0.1536242961883545  seconds
# Deleting event Nest3_ (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Nest3_"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventNest3' from '..\\lmtanalysis\\BuildEventNest3.py'>  ]  0.0807492733001709  seconds
# Deleting event Nest4_ (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Nest4_"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventNest4' from '..\\lmtanalysis\\BuildEventNest4.py'>  ]  0.07682919502258301  seconds
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849328 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004849341 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004849362 Genotype:None User1:None
# nb animals:  3
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Correct wrong animal','0','2020-03-26 16:13:18','0','332427' );
# Rebuild event finished.
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849328 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004849341 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004849362 Genotype:None User1:None
# Detection
# Event Detection created. eventNameWithId = Detection idA:1 idB:None idC:None idD:None loadEvent: False
# processing animal ID: 1
# SELECT FRAMENUMBER FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=332427
#  detections loaded in 0.870805025100708 seconds.
# Number of event:  292
# Mean length of event:  919.6027397260274
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Detection ( 292 events )
# Detection
# Event Detection created. eventNameWithId = Detection idA:2 idB:None idC:None idD:None loadEvent: False
# processing animal ID: 2
# SELECT FRAMENUMBER FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=332427
#  detections loaded in 1.1394579410552979 seconds.
# Number of event:  1029
# Mean length of event:  290.6618075801749
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Detection ( 1029 events )
# Detection
# Event Detection created. eventNameWithId = Detection idA:3 idB:None idC:None idD:None loadEvent: False
# processing animal ID: 3
# SELECT FRAMENUMBER FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=332427
#  detections loaded in 0.9945359230041504 seconds.
# Number of event:  600
# Mean length of event:  493.315
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Detection ( 600 events )
# Detection
# Event Detection created. eventNameWithId = Detection idA:4 idB:None idC:None idD:None loadEvent: False
# processing animal ID: 4
# SELECT FRAMENUMBER FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=332427
#  detections loaded in 0.0 seconds.
# no event
# Keep previous entry.
# Saving timeLine: Detection ( 0 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Detection','0','2020-03-26 16:13:22','0','332427' );
# Rebuild event finished.
# Caching load of animal detection...
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849328 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004849341 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004849362 Genotype:None User1:None
# Animal Id:1 Name:A RFID:000004849328 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=332427
# Animal Id:1 Name:A RFID:000004849328 Genotype:None User1:None   268523  detections loaded in 5.874261856079102 seconds.
# Animal Id:2 Name:B RFID:000004849341 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=332427
# Animal Id:2 Name:B RFID:000004849341 Genotype:None User1:None   299087  detections loaded in 7.054056882858276 seconds.
# Animal Id:3 Name:C RFID:000004849362 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=332427
# Animal Id:3 Name:C RFID:000004849362 Genotype:None User1:None   295984  detections loaded in 6.7508111000061035 seconds.
# Caching load of animal detection done.
# Oral-oral Contact
# Event Oral-oral Contact created. eventNameWithId = Oral-oral Contact idA:1 idB:2 idC:None idD:None loadEvent: False
# Number of event:  2194
# Mean length of event:  6.7666362807657245
# first event frame:  1252
# Keep previous entry.
# Saving timeLine: Oral-oral Contact ( 2194 events )
# Oral-oral Contact
# Event Oral-oral Contact created. eventNameWithId = Oral-oral Contact idA:1 idB:3 idC:None idD:None loadEvent: False
# Number of event:  2399
# Mean length of event:  4.3772405168820345
# first event frame:  122
# Keep previous entry.
# Saving timeLine: Oral-oral Contact ( 2399 events )
# Oral-oral Contact
# Event Oral-oral Contact created. eventNameWithId = Oral-oral Contact idA:2 idB:1 idC:None idD:None loadEvent: False
# Number of event:  2194
# Mean length of event:  6.7666362807657245
# first event frame:  1252
# Keep previous entry.
# Saving timeLine: Oral-oral Contact ( 2194 events )
# Oral-oral Contact
# Event Oral-oral Contact created. eventNameWithId = Oral-oral Contact idA:2 idB:3 idC:None idD:None loadEvent: False
# Number of event:  1996
# Mean length of event:  5.278557114228457
# first event frame:  58
# Keep previous entry.
# Saving timeLine: Oral-oral Contact ( 1996 events )
# Oral-oral Contact
# Event Oral-oral Contact created. eventNameWithId = Oral-oral Contact idA:3 idB:1 idC:None idD:None loadEvent: False
# Number of event:  2399
# Mean length of event:  4.3772405168820345
# first event frame:  122
# Keep previous entry.
# Saving timeLine: Oral-oral Contact ( 2399 events )
# Oral-oral Contact
# Event Oral-oral Contact created. eventNameWithId = Oral-oral Contact idA:3 idB:2 idC:None idD:None loadEvent: False
# Number of event:  1996
# Mean length of event:  5.278557114228457
# first event frame:  58
# Keep previous entry.
# Saving timeLine: Oral-oral Contact ( 1996 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Oral Oral Contact','0','2020-03-26 16:13:46','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventOralOralContact' from '..\\lmtanalysis\\BuildEventOralOralContact.py'>  ]  4.329992771148682  seconds
# Oral-genital Contact
# Event Oral-genital Contact created. eventNameWithId = Oral-genital Contact idA:1 idB:2 idC:None idD:None loadEvent: False
# Number of event:  2067
# Mean length of event:  4.1257861635220126
# first event frame:  1261
# Keep previous entry.
# Saving timeLine: Oral-genital Contact ( 2067 events )
# Oral-genital Contact
# Event Oral-genital Contact created. eventNameWithId = Oral-genital Contact idA:1 idB:3 idC:None idD:None loadEvent: False
# Number of event:  2471
# Mean length of event:  4.406717927964387
# first event frame:  386
# Keep previous entry.
# Saving timeLine: Oral-genital Contact ( 2471 events )
# Oral-genital Contact
# Event Oral-genital Contact created. eventNameWithId = Oral-genital Contact idA:2 idB:1 idC:None idD:None loadEvent: False
# Number of event:  2211
# Mean length of event:  4.907734056987788
# first event frame:  2491
# Keep previous entry.
# Saving timeLine: Oral-genital Contact ( 2211 events )
# Oral-genital Contact
# Event Oral-genital Contact created. eventNameWithId = Oral-genital Contact idA:2 idB:3 idC:None idD:None loadEvent: False
# Number of event:  2540
# Mean length of event:  4.001181102362205
# first event frame:  108
# Keep previous entry.
# Saving timeLine: Oral-genital Contact ( 2540 events )
# Oral-genital Contact
# Event Oral-genital Contact created. eventNameWithId = Oral-genital Contact idA:3 idB:1 idC:None idD:None loadEvent: False
# Number of event:  2688
# Mean length of event:  3.5238095238095237
# first event frame:  143
# Keep previous entry.
# Saving timeLine: Oral-genital Contact ( 2688 events )
# Oral-genital Contact
# Event Oral-genital Contact created. eventNameWithId = Oral-genital Contact idA:3 idB:2 idC:None idD:None loadEvent: False
# Number of event:  1834
# Mean length of event:  4.506543075245365
# first event frame:  95
# Keep previous entry.
# Saving timeLine: Oral-genital Contact ( 1834 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Oral Genital Contact','0','2020-03-26 16:13:51','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventOralGenitalContact' from '..\\lmtanalysis\\BuildEventOralGenitalContact.py'>  ]  4.923256158828735  seconds
# Side by side Contact
# Event Side by side Contact created. eventNameWithId = Side by side Contact idA:1 idB:2 idC:None idD:None loadEvent: False
# Number of event:  2524
# Mean length of event:  10.397385103011093
# first event frame:  2394
# Keep previous entry.
# Saving timeLine: Side by side Contact ( 2524 events )
# Side by side Contact
# Event Side by side Contact created. eventNameWithId = Side by side Contact idA:1 idB:3 idC:None idD:None loadEvent: False
# Number of event:  1919
# Mean length of event:  9.050026055237103
# first event frame:  122
# Keep previous entry.
# Saving timeLine: Side by side Contact ( 1919 events )
# Side by side Contact
# Event Side by side Contact created. eventNameWithId = Side by side Contact idA:2 idB:1 idC:None idD:None loadEvent: False
# Number of event:  2524
# Mean length of event:  10.397385103011093
# first event frame:  2394
# Keep previous entry.
# Saving timeLine: Side by side Contact ( 2524 events )
# Side by side Contact
# Event Side by side Contact created. eventNameWithId = Side by side Contact idA:2 idB:3 idC:None idD:None loadEvent: False
# Number of event:  1715
# Mean length of event:  8.367930029154518
# first event frame:  1059
# Keep previous entry.
# Saving timeLine: Side by side Contact ( 1715 events )
# Side by side Contact
# Event Side by side Contact created. eventNameWithId = Side by side Contact idA:3 idB:1 idC:None idD:None loadEvent: False
# Number of event:  1919
# Mean length of event:  9.050026055237103
# first event frame:  122
# Keep previous entry.
# Saving timeLine: Side by side Contact ( 1919 events )
# Side by side Contact
# Event Side by side Contact created. eventNameWithId = Side by side Contact idA:3 idB:2 idC:None idD:None loadEvent: False
# Number of event:  1715
# Mean length of event:  8.367930029154518
# first event frame:  1059
# Keep previous entry.
# Saving timeLine: Side by side Contact ( 1715 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Side by side','0','2020-03-26 16:13:57','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventSideBySide' from '..\\lmtanalysis\\BuildEventSideBySide.py'>  ]  6.265259027481079  seconds
# Side by side Contact, opposite way
# Event Side by side Contact, opposite way created. eventNameWithId = Side by side Contact, opposite way idA:1 idB:2 idC:None idD:None loadEvent: False
# Number of event:  1617
# Mean length of event:  10.622139764996907
# first event frame:  2491
# Keep previous entry.
# Saving timeLine: Side by side Contact, opposite way ( 1617 events )
# Side by side Contact, opposite way
# Event Side by side Contact, opposite way created. eventNameWithId = Side by side Contact, opposite way idA:1 idB:3 idC:None idD:None loadEvent: False
# Number of event:  2022
# Mean length of event:  9.456973293768545
# first event frame:  118
# Keep previous entry.
# Saving timeLine: Side by side Contact, opposite way ( 2022 events )
# Side by side Contact, opposite way
# Event Side by side Contact, opposite way created. eventNameWithId = Side by side Contact, opposite way idA:2 idB:1 idC:None idD:None loadEvent: False
# Number of event:  1617
# Mean length of event:  10.622139764996907
# first event frame:  2491
# Keep previous entry.
# Saving timeLine: Side by side Contact, opposite way ( 1617 events )
# Side by side Contact, opposite way
# Event Side by side Contact, opposite way created. eventNameWithId = Side by side Contact, opposite way idA:2 idB:3 idC:None idD:None loadEvent: False
# Number of event:  1900
# Mean length of event:  7.768947368421053
# first event frame:  95
# Keep previous entry.
# Saving timeLine: Side by side Contact, opposite way ( 1900 events )
# Side by side Contact, opposite way
# Event Side by side Contact, opposite way created. eventNameWithId = Side by side Contact, opposite way idA:3 idB:1 idC:None idD:None loadEvent: False
# Number of event:  2022
# Mean length of event:  9.456973293768545
# first event frame:  118
# Keep previous entry.
# Saving timeLine: Side by side Contact, opposite way ( 2022 events )
# Side by side Contact, opposite way
# Event Side by side Contact, opposite way created. eventNameWithId = Side by side Contact, opposite way idA:3 idB:2 idC:None idD:None loadEvent: False
# Number of event:  1900
# Mean length of event:  7.768947368421053
# first event frame:  95
# Keep previous entry.
# Saving timeLine: Side by side Contact, opposite way ( 1900 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Side by side opposite','0','2020-03-26 16:14:04','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventSideBySideOpposite' from '..\\lmtanalysis\\BuildEventSideBySideOpposite.py'>  ]  6.603414058685303  seconds
# Oral-genital Contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 2067  records loaded in  0.37699317932128906 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 2471  records loaded in  0.42636871337890625 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 2211  records loaded in  0.6146924495697021 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 2540  records loaded in  0.5117928981781006 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 2688  records loaded in  0.3965306282043457 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 1834  records loaded in  0.3411252498626709 S )
# Caching eventTimeLine
# Train2
# Event Train2 created. eventNameWithId = Train2 idA:1 idB:2 idC:None idD:None loadEvent: False
# Number of event:  12
# Mean length of event:  7.916666666666667
# first event frame:  6147
# Keep previous entry.
# Saving timeLine: Train2 ( 12 events )
# Train2
# Event Train2 created. eventNameWithId = Train2 idA:1 idB:3 idC:None idD:None loadEvent: False
# Number of event:  9
# Mean length of event:  7.666666666666667
# first event frame:  4174
# Keep previous entry.
# Saving timeLine: Train2 ( 9 events )
# Train2
# Event Train2 created. eventNameWithId = Train2 idA:2 idB:1 idC:None idD:None loadEvent: False
# Number of event:  12
# Mean length of event:  7.5
# first event frame:  17289
# Keep previous entry.
# Saving timeLine: Train2 ( 12 events )
# Train2
# Event Train2 created. eventNameWithId = Train2 idA:2 idB:3 idC:None idD:None loadEvent: False
# Number of event:  6
# Mean length of event:  9.5
# first event frame:  11182
# Keep previous entry.
# Saving timeLine: Train2 ( 6 events )
# Train2
# Event Train2 created. eventNameWithId = Train2 idA:3 idB:1 idC:None idD:None loadEvent: False
# Number of event:  3
# Mean length of event:  5.0
# first event frame:  5307
# Keep previous entry.
# Saving timeLine: Train2 ( 3 events )
# Train2
# Event Train2 created. eventNameWithId = Train2 idA:3 idB:2 idC:None idD:None loadEvent: False
# Number of event:  3
# Mean length of event:  8.0
# first event frame:  18013
# Keep previous entry.
# Saving timeLine: Train2 ( 3 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Train2','0','2020-03-26 16:14:07','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventTrain2' from '..\\lmtanalysis\\BuildEventTrain2.py'>  ]  2.963925361633301  seconds
# Train2  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 12  records loaded in  0.3310997486114502 S )
# Caching eventTimeLine
# Train2  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 9  records loaded in  0.3502190113067627 S )
# Caching eventTimeLine
# Train2  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 0  records loaded in  0.43013429641723633 S )
# Caching eventTimeLine
# Train2  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 12  records loaded in  0.39246273040771484 S )
# Caching eventTimeLine
# Train2  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 6  records loaded in  0.3475914001464844 S )
# Caching eventTimeLine
# Train2  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 0  records loaded in  0.3422377109527588 S )
# Caching eventTimeLine
# Train2  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 3  records loaded in  0.3231358528137207 S )
# Caching eventTimeLine
# Train2  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 3  records loaded in  0.42985057830810547 S )
# Caching eventTimeLine
# Train2  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 0  records loaded in  0.4408421516418457 S )
# Caching eventTimeLine
# Train2  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 0  records loaded in  0.4336514472961426 S )
# Caching eventTimeLine
# Train2  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 0  records loaded in  0.4518420696258545 S )
# Caching eventTimeLine
# Train2  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 0  records loaded in  0.4248642921447754 S )
# Caching eventTimeLine
# Event Train3 created. eventNameWithId = Train3 idA:1 idB:3 idC:2 idD:None loadEvent: False
# Number of event:  1
# Mean length of event:  5.0
# first event frame:  18017
# Keep previous entry.
# Saving timeLine: Train3 ( 1 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Train3','0','2020-03-26 16:14:11','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventTrain3' from '..\\lmtanalysis\\BuildEventTrain3.py'>  ]  4.755777835845947  seconds
# Train2  Id( 1 , 2 , None , None ) Loaded from cache ( 12  records. )
# Train2  Id( 1 , 3 , None , None ) Loaded from cache ( 9  records. )
# Train2  Id( 2 , 1 , None , None ) Loaded from cache ( 12  records. )
# Train2  Id( 2 , 3 , None , None ) Loaded from cache ( 6  records. )
# Train2  Id( 3 , 1 , None , None ) Loaded from cache ( 3  records. )
# Train2  Id( 3 , 2 , None , None ) Loaded from cache ( 3  records. )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Train4','0','2020-03-26 16:14:11','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventTrain4' from '..\\lmtanalysis\\BuildEventTrain4.py'>  ]  0.018949270248413086  seconds
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849328 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004849341 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004849362 Genotype:None User1:None
# Stop  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 4452  records loaded in  0.7579774856567383 S )
# Detection  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 292  records loaded in  0.8372282981872559 S )
# Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 1096  records loaded in  0.5201666355133057 S )
# Caching eventTimeLine
# Stop  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 5825  records loaded in  0.4939548969268799 S )
# Detection  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 1029  records loaded in  0.6500093936920166 S )
# Contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 1107  records loaded in  0.5121400356292725 S )
# Caching eventTimeLine
# Stop  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 5306  records loaded in  0.6543886661529541 S )
# Detection  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 600  records loaded in  0.5244946479797363 S )
# Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 1053  records loaded in  0.5275897979736328 S )
# Caching eventTimeLine
# Event Move created. eventNameWithId = Move idA:1 idB:None idC:None idD:None loadEvent: False
# Number of event:  4631
# Mean length of event:  10.396242712157202
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Move ( 4631 events )
# Event Move isolated created. eventNameWithId = Move isolated idA:1 idB:None idC:None idD:None loadEvent: False
# Number of event:  3114
# Mean length of event:  11.76878612716763
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Move isolated ( 3114 events )
# Event Move in contact created. eventNameWithId = Move in contact idA:1 idB:None idC:None idD:None loadEvent: False
# Number of event:  2439
# Mean length of event:  4.713817138171382
# first event frame:  120
# Keep previous entry.
# Saving timeLine: Move in contact ( 2439 events )
# Event Move created. eventNameWithId = Move idA:2 idB:None idC:None idD:None loadEvent: False
# Number of event:  6022
# Mean length of event:  9.232480903354368
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Move ( 6022 events )
# Event Move isolated created. eventNameWithId = Move isolated idA:2 idB:None idC:None idD:None loadEvent: False
# Number of event:  4230
# Mean length of event:  9.959810874704491
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Move isolated ( 4230 events )
# Event Move in contact created. eventNameWithId = Move in contact idA:2 idB:None idC:None idD:None loadEvent: False
# Number of event:  2899
# Mean length of event:  4.645739910313901
# first event frame:  93
# Keep previous entry.
# Saving timeLine: Move in contact ( 2899 events )
# Event Move created. eventNameWithId = Move idA:3 idB:None idC:None idD:None loadEvent: False
# Number of event:  5547
# Mean length of event:  9.310257797007392
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Move ( 5547 events )
# Event Move isolated created. eventNameWithId = Move isolated idA:3 idB:None idC:None idD:None loadEvent: False
# Number of event:  3832
# Mean length of event:  10.644050104384133
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Move isolated ( 3832 events )
# Event Move in contact created. eventNameWithId = Move in contact idA:3 idB:None idC:None idD:None loadEvent: False
# Number of event:  2552
# Mean length of event:  4.253918495297806
# first event frame:  53
# Keep previous entry.
# Saving timeLine: Move in contact ( 2552 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Move','0','2020-03-26 16:14:23','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventMove' from '..\\lmtanalysis\\BuildEventMove.py'>  ]  11.831419467926025  seconds
# Animal Id:1 Name:A RFID:000004849328 Genotype:None User1:None
# mean animal bodysize:  32.92868207448673
# Contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 1604  records loaded in  0.8098387718200684 S )
# Caching eventTimeLine
# Contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 1905  records loaded in  0.7350344657897949 S )
# Caching eventTimeLine
# Animal Id:2 Name:B RFID:000004849341 Genotype:None User1:None
# mean animal bodysize:  32.273018391207174
# Contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 1604  records loaded in  0.578129768371582 S )
# Caching eventTimeLine
# Contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 2715  records loaded in  0.6517682075500488 S )
# Caching eventTimeLine
# Animal Id:3 Name:C RFID:000004849362 Genotype:None User1:None
# mean animal bodysize:  32.28547760716688
# Contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 1905  records loaded in  0.6298995018005371 S )
# Caching eventTimeLine
# Contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 2715  records loaded in  0.6293401718139648 S )
# Caching eventTimeLine
# A follow B
# FollowZone Isolated
# Event FollowZone Isolated created. eventNameWithId = FollowZone Isolated idA:2 idB:1 idC:None idD:None loadEvent: False
# FollowZone Isolated idA:2 idB:1 idC:None idD:None
# Number of event:  885
# Mean length of event:  2.0440677966101695
# first event frame:  2419
# Keep previous entry.
# Saving timeLine: FollowZone Isolated ( 885 events )
# A follow B
# FollowZone Isolated
# Event FollowZone Isolated created. eventNameWithId = FollowZone Isolated idA:3 idB:1 idC:None idD:None loadEvent: False
# FollowZone Isolated idA:3 idB:1 idC:None idD:None
# Number of event:  521
# Mean length of event:  1.5374280230326296
# first event frame:  150
# Keep previous entry.
# Saving timeLine: FollowZone Isolated ( 521 events )
# A follow B
# FollowZone Isolated
# Event FollowZone Isolated created. eventNameWithId = FollowZone Isolated idA:1 idB:2 idC:None idD:None loadEvent: False
# FollowZone Isolated idA:1 idB:2 idC:None idD:None
# Number of event:  896
# Mean length of event:  1.8404017857142858
# first event frame:  2432
# Keep previous entry.
# Saving timeLine: FollowZone Isolated ( 896 events )
# A follow B
# FollowZone Isolated
# Event FollowZone Isolated created. eventNameWithId = FollowZone Isolated idA:3 idB:2 idC:None idD:None loadEvent: False
# FollowZone Isolated idA:3 idB:2 idC:None idD:None
# Number of event:  349
# Mean length of event:  1.7392550143266476
# first event frame:  5611
# Keep previous entry.
# Saving timeLine: FollowZone Isolated ( 349 events )
# A follow B
# FollowZone Isolated
# Event FollowZone Isolated created. eventNameWithId = FollowZone Isolated idA:1 idB:3 idC:None idD:None loadEvent: False
# FollowZone Isolated idA:1 idB:3 idC:None idD:None
# Number of event:  526
# Mean length of event:  1.8231939163498099
# first event frame:  123
# Keep previous entry.
# Saving timeLine: FollowZone Isolated ( 526 events )
# A follow B
# FollowZone Isolated
# Event FollowZone Isolated created. eventNameWithId = FollowZone Isolated idA:2 idB:3 idC:None idD:None loadEvent: False
# FollowZone Isolated idA:2 idB:3 idC:None idD:None
# Number of event:  513
# Mean length of event:  2.1052631578947367
# first event frame:  1683
# Keep previous entry.
# Saving timeLine: FollowZone Isolated ( 513 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Follow Zone','0','2020-03-26 16:14:43','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventFollowZone' from '..\\lmtanalysis\\BuildEventFollowZone.py'>  ]  19.874666213989258  seconds
# Animal Id:1 Name:A RFID:000004849328 Genotype:None User1:None
# Contact  Id( 1 , None , None , None ) Loaded from cache ( 1096  records. )
# A rears
# Event Rear in contact created. eventNameWithId = Rear in contact idA:1 idB:None idC:None idD:None loadEvent: False
# Event Rear isolated created. eventNameWithId = Rear isolated idA:1 idB:None idC:None idD:None loadEvent: False
# Number of event:  2095
# Mean length of event:  2.7918854415274463
# first event frame:  2383
# Keep previous entry.
# Saving timeLine: Rear in contact ( 2095 events )
# Number of event:  1652
# Mean length of event:  3.943099273607748
# first event frame:  78
# Keep previous entry.
# Saving timeLine: Rear isolated ( 1652 events )
# Animal Id:2 Name:B RFID:000004849341 Genotype:None User1:None
# Contact  Id( 2 , None , None , None ) Loaded from cache ( 1107  records. )
# A rears
# Event Rear in contact created. eventNameWithId = Rear in contact idA:2 idB:None idC:None idD:None loadEvent: False
# Event Rear isolated created. eventNameWithId = Rear isolated idA:2 idB:None idC:None idD:None loadEvent: False
# Number of event:  1832
# Mean length of event:  2.4519650655021836
# first event frame:  67
# Keep previous entry.
# Saving timeLine: Rear in contact ( 1832 events )
# Number of event:  1408
# Mean length of event:  3.588778409090909
# first event frame:  35
# Keep previous entry.
# Saving timeLine: Rear isolated ( 1408 events )
# Animal Id:3 Name:C RFID:000004849362 Genotype:None User1:None
# Contact  Id( 3 , None , None , None ) Loaded from cache ( 1053  records. )
# A rears
# Event Rear in contact created. eventNameWithId = Rear in contact idA:3 idB:None idC:None idD:None loadEvent: False
# Event Rear isolated created. eventNameWithId = Rear isolated idA:3 idB:None idC:None idD:None loadEvent: False
# Number of event:  1597
# Mean length of event:  2.886662492172824
# first event frame:  64
# Keep previous entry.
# Saving timeLine: Rear in contact ( 1597 events )
# Number of event:  1924
# Mean length of event:  3.2863825363825363
# first event frame:  256
# Keep previous entry.
# Saving timeLine: Rear isolated ( 1924 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Rear5','0','2020-03-26 16:14:46','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventRear5' from '..\\lmtanalysis\\BuildEventRear5.py'>  ]  2.6853549480438232  seconds
# Approach  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 19426  records loaded in  0.9020981788635254 S )
# Caching eventTimeLine
# Approach  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 18333  records loaded in  0.7484278678894043 S )
# Caching eventTimeLine
# Approach  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 22012  records loaded in  0.6634421348571777 S )
# Caching eventTimeLine
# Approach  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 24001  records loaded in  0.8267929553985596 S )
# Caching eventTimeLine
# Approach  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 19449  records loaded in  1.3308699131011963 S )
# Caching eventTimeLine
# Approach  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 22885  records loaded in  1.5339312553405762 S )
# Caching eventTimeLine
# mean animal bodysize:  32.92870248369517
# mean animal bodysize:  32.27300783420974
# mean animal bodysize:  32.285458783502136
# Social approach
# Event Social approach created. eventNameWithId = Social approach idA:1 idB:2 idC:None idD:None loadEvent: False
# Number of event:  15010
# Mean length of event:  1.9692205196535644
# first event frame:  303
# Keep previous entry.
# Saving timeLine: Social approach ( 15010 events )
# Social approach
# Event Social approach created. eventNameWithId = Social approach idA:1 idB:3 idC:None idD:None loadEvent: False
# Number of event:  13329
# Mean length of event:  2.140070522919949
# first event frame:  119
# Keep previous entry.
# Saving timeLine: Social approach ( 13329 events )
# Social approach
# Event Social approach created. eventNameWithId = Social approach idA:2 idB:1 idC:None idD:None loadEvent: False
# Number of event:  18096
# Mean length of event:  2.004862953138815
# first event frame:  297
# Keep previous entry.
# Saving timeLine: Social approach ( 18096 events )
# Social approach
# Event Social approach created. eventNameWithId = Social approach idA:2 idB:3 idC:None idD:None loadEvent: False
# Number of event:  17397
# Mean length of event:  2.078001954359947
# first event frame:  61
# Keep previous entry.
# Saving timeLine: Social approach ( 17397 events )
# Social approach
# Event Social approach created. eventNameWithId = Social approach idA:3 idB:1 idC:None idD:None loadEvent: False
# Number of event:  14150
# Mean length of event:  2.0366784452296818
# first event frame:  121
# Keep previous entry.
# Saving timeLine: Social approach ( 14150 events )
# Social approach
# Event Social approach created. eventNameWithId = Social approach idA:3 idB:2 idC:None idD:None loadEvent: False
# Number of event:  15820
# Mean length of event:  1.9504424778761063
# first event frame:  47
# Keep previous entry.
# Saving timeLine: Social approach ( 15820 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Social Approach','0','2020-03-26 16:15:05','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventSocialApproach' from '..\\lmtanalysis\\BuildEventSocialApproach.py'>  ]  18.885634899139404  seconds
# Escape
# Get away
# Event Get away created. eventNameWithId = Get away idA:1 idB:2 idC:None idD:None loadEvent: False
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# Number of event:  9074
# Mean length of event:  2.8729336566012784
# first event frame:  50
# Keep previous entry.
# Saving timeLine: Get away ( 9074 events )
# Get away
# Event Get away created. eventNameWithId = Get away idA:1 idB:3 idC:None idD:None loadEvent: False
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# Number of event:  8845
# Mean length of event:  3.0271339739966083
# first event frame:  55
# Keep previous entry.
# Saving timeLine: Get away ( 8845 events )
# Get away
# Event Get away created. eventNameWithId = Get away idA:2 idB:1 idC:None idD:None loadEvent: False
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# ...
# Event NovObj Interact created. eventNameWithId = NovObj Interact idA:1 idB:None idC:None idD:None loadEvent: False
# Stop  Id( 1 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 4451  records loaded in  0.40249085426330566 S )
# Caching eventTimeLine
# Number of event:  222
# Mean length of event:  29.37837837837838
# first event frame:  1419
# Keep previous entry.
# Saving timeLine: NovObj Zone ( 222 events )
# Number of event:  314
# Mean length of event:  27.455414012738853
# first event frame:  14
# Keep previous entry.
# Saving timeLine: NovObj Stop ( 314 events )
# Number of event:  224
# Mean length of event:  38.17857142857143
# first event frame:  15
# Keep previous entry.
# Saving timeLine: NovObj Interact ( 224 events )
# Animal Id:2 Name:B RFID:000004849341 Genotype:None User1:None
# A is in the zone around the novel object source
# NovObj Zone
# Event NovObj Zone created. eventNameWithId = NovObj Zone idA:2 idB:None idC:None idD:None loadEvent: False
# Event NovObj Stop created. eventNameWithId = NovObj Stop idA:2 idB:None idC:None idD:None loadEvent: False
# Event NovObj Interact created. eventNameWithId = NovObj Interact idA:2 idB:None idC:None idD:None loadEvent: False
# Stop  Id( 2 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 5824  records loaded in  0.5580174922943115 S )
# Caching eventTimeLine
# Number of event:  114
# Mean length of event:  42.50877192982456
# first event frame:  2803
# Keep previous entry.
# Saving timeLine: NovObj Zone ( 114 events )
# Number of event:  193
# Mean length of event:  32.64248704663213
# first event frame:  221
# Keep previous entry.
# Saving timeLine: NovObj Stop ( 193 events )
# Number of event:  147
# Mean length of event:  42.136054421768705
# first event frame:  241
# Keep previous entry.
# Saving timeLine: NovObj Interact ( 147 events )
# Animal Id:3 Name:C RFID:000004849362 Genotype:None User1:None
# A is in the zone around the novel object source
# NovObj Zone
# Event NovObj Zone created. eventNameWithId = NovObj Zone idA:3 idB:None idC:None idD:None loadEvent: False
# Event NovObj Stop created. eventNameWithId = NovObj Stop idA:3 idB:None idC:None idD:None loadEvent: False
# Event NovObj Interact created. eventNameWithId = NovObj Interact idA:3 idB:None idC:None idD:None loadEvent: False
# Stop  Id( 3 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 5305  records loaded in  0.3498342037200928 S )
# Caching eventTimeLine
# Number of event:  164
# Mean length of event:  55.44512195121951
# first event frame:  587
# Keep previous entry.
# Saving timeLine: NovObj Zone ( 164 events )
# Number of event:  228
# Mean length of event:  51.53947368421053
# first event frame:  582
# Keep previous entry.
# Saving timeLine: NovObj Stop ( 228 events )
# Number of event:  190
# Mean length of event:  57.94210526315789
# first event frame:  576
# Keep previous entry.
# Saving timeLine: NovObj Interact ( 190 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Novel Object','0','2020-03-26 17:20:19','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventNovObj_Interaction' from '..\\lmtanalysis\\BuildEventNovObj_Interaction.py'>  ]  9.716404914855957  seconds
# Contact  Id( 1 , 2 , None , None ) Loaded from cache ( 1604  records. )
# Social approach  Id( 1 , 2 , None , None ) Loaded from cache ( 15010  records. )
# Contact  Id( 1 , 3 , None , None ) Loaded from cache ( 1905  records. )
# Social approach  Id( 1 , 3 , None , None ) Loaded from cache ( 13329  records. )
# Contact  Id( 2 , 1 , None , None ) Loaded from cache ( 1604  records. )
# Social approach  Id( 2 , 1 , None , None ) Loaded from cache ( 18096  records. )
# Contact  Id( 2 , 3 , None , None ) Loaded from cache ( 2715  records. )
# Social approach  Id( 2 , 3 , None , None ) Loaded from cache ( 17397  records. )
# Contact  Id( 3 , 1 , None , None ) Loaded from cache ( 1905  records. )
# Social approach  Id( 3 , 1 , None , None ) Loaded from cache ( 14150  records. )
# Contact  Id( 3 , 2 , None , None ) Loaded from cache ( 2715  records. )
# Social approach  Id( 3 , 2 , None , None ) Loaded from cache ( 15820  records. )
# Approach contact
# Event Approach contact created. eventNameWithId = Approach contact idA:1 idB:2 idC:None idD:None loadEvent: False
# Number of event:  12353
# Mean length of event:  2.0198332388893387
# first event frame:  669
# Keep previous entry.
# Saving timeLine: Approach contact ( 12353 events )
# Approach contact
# Event Approach contact created. eventNameWithId = Approach contact idA:1 idB:3 idC:None idD:None loadEvent: False
# Number of event:  9494
# Mean length of event:  2.2713292605856332
# first event frame:  119
# Keep previous entry.
# Saving timeLine: Approach contact ( 9494 events )
# Approach contact
# Event Approach contact created. eventNameWithId = Approach contact idA:2 idB:1 idC:None idD:None loadEvent: False
# Number of event:  14839
# Mean length of event:  2.0364579823438236
# first event frame:  2412
# Keep previous entry.
# Saving timeLine: Approach contact ( 14839 events )
# Approach contact
# Event Approach contact created. eventNameWithId = Approach contact idA:2 idB:3 idC:None idD:None loadEvent: False
# Number of event:  9372
# Mean length of event:  2.344857020913359
# first event frame:  61
# Keep previous entry.
# Saving timeLine: Approach contact ( 9372 events )
# Approach contact
# Event Approach contact created. eventNameWithId = Approach contact idA:3 idB:1 idC:None idD:None loadEvent: False
# Number of event:  11687
# Mean length of event:  2.081458030290066
# first event frame:  121
# Keep previous entry.
# Saving timeLine: Approach contact ( 11687 events )
# Approach contact
# Event Approach contact created. eventNameWithId = Approach contact idA:3 idB:2 idC:None idD:None loadEvent: False
# Number of event:  9582
# Mean length of event:  2.1482988937591316
# first event frame:  47
# Keep previous entry.
# Saving timeLine: Approach contact ( 9582 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Approach Contact','0','2020-03-26 17:20:27','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventApproachContact' from '..\\lmtanalysis\\BuildEventApproachContact.py'>  ]  7.875360727310181  seconds
# Animal Id:1 Name:A RFID:000004849328 Genotype:None User1:None
# A is jumping against the wall
# WallJump
# Event WallJump created. eventNameWithId = WallJump idA:1 idB:None idC:None idD:None loadEvent: False
# Number of event:  198
# Mean length of event:  2.176767676767677
# first event frame:  1185
# Keep previous entry.
# Saving timeLine: WallJump ( 198 events )
# Animal Id:2 Name:B RFID:000004849341 Genotype:None User1:None
# A is jumping against the wall
# WallJump
# Event WallJump created. eventNameWithId = WallJump idA:2 idB:None idC:None idD:None loadEvent: False
# Number of event:  195
# Mean length of event:  2.2256410256410257
# first event frame:  2288
# Keep previous entry.
# Saving timeLine: WallJump ( 195 events )
# Animal Id:3 Name:C RFID:000004849362 Genotype:None User1:None
# A is jumping against the wall
# WallJump
# Event WallJump created. eventNameWithId = WallJump idA:3 idB:None idC:None idD:None loadEvent: False
# Number of event:  159
# Mean length of event:  2.2264150943396226
# first event frame:  2397
# Keep previous entry.
# Saving timeLine: WallJump ( 159 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Wall Jump','0','2020-03-26 17:20:46','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventWallJump' from '..\\lmtanalysis\\BuildEventWallJump.py'>  ]  18.895604372024536  seconds
# Event SAP created. eventNameWithId = SAP idA:1 idB:None idC:None idD:None loadEvent: False
# Number of event:  2010
# Mean length of event:  4.003482587064677
# first event frame:  36
# Keep previous entry.
# Saving timeLine: SAP ( 2010 events )
# Event SAP created. eventNameWithId = SAP idA:2 idB:None idC:None idD:None loadEvent: False
# Number of event:  1806
# Mean length of event:  3.6068660022148396
# first event frame:  230
# Keep previous entry.
# Saving timeLine: SAP ( 1806 events )
# Event SAP created. eventNameWithId = SAP idA:3 idB:None idC:None idD:None loadEvent: False
# Number of event:  2779
# Mean length of event:  5.8654192155451605
# first event frame:  96
# Keep previous entry.
# Saving timeLine: SAP ( 2779 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event SAP','0','2020-03-26 17:20:50','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventSAP' from '..\\lmtanalysis\\BuildEventSAP.py'>  ]  4.7678844928741455  seconds
# Animal Id:1 Name:A RFID:000004849328 Genotype:None User1:None
# mean animal bodysize:  32.92868207448673
# Oral-oral Contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 2194  records loaded in  1.2151002883911133 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 2 , 1 , None , None ) Loaded from cache ( 2211  records. )
# Oral-oral Contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 2399  records loaded in  1.10915207862854 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 3 , 1 , None , None ) Loaded from cache ( 2688  records. )
# Animal Id:2 Name:B RFID:000004849341 Genotype:None User1:None
# mean animal bodysize:  32.273018391207174
# Oral-oral Contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 2194  records loaded in  1.111907720565796 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 1 , 2 , None , None ) Loaded from cache ( 2067  records. )
# Oral-oral Contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 1996  records loaded in  0.9639880657196045 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 3 , 2 , None , None ) Loaded from cache ( 1834  records. )
# Animal Id:3 Name:C RFID:000004849362 Genotype:None User1:None
# mean animal bodysize:  32.28547760716688
# Oral-oral Contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 2399  records loaded in  1.124394178390503 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 1 , 3 , None , None ) Loaded from cache ( 2471  records. )
# Oral-oral Contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 332427 ) Loaded ( 1996  records loaded in  1.0362293720245361 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 2 , 3 , None , None ) Loaded from cache ( 2540  records. )
# seq oral oral - oral genital
# Event seq oral oral - oral genital created. eventNameWithId = seq oral oral - oral genital idA:1 idB:2 idC:None idD:None loadEvent: False
# seq oral oral - oral genital idA:1 idB:2 idC:None idD:None
# Number of event:  61
# Mean length of event:  55.42622950819672
# first event frame:  5988
# Keep previous entry.
# Saving timeLine: seq oral oral - oral genital ( 61 events )
# Event seq oral oral - oral genital created. eventNameWithId = seq oral oral - oral genital idA:1 idB:3 idC:None idD:None loadEvent: False
# seq oral oral - oral genital idA:1 idB:3 idC:None idD:None
# Number of event:  70
# Mean length of event:  58.357142857142854
# first event frame:  4233
# Keep previous entry.
# Saving timeLine: seq oral oral - oral genital ( 70 events )
# Event seq oral oral - oral genital created. eventNameWithId = seq oral oral - oral genital idA:2 idB:1 idC:None idD:None loadEvent: False
# seq oral oral - oral genital idA:2 idB:1 idC:None idD:None
# Number of event:  83
# Mean length of event:  61.1566265060241
# first event frame:  2891
# Keep previous entry.
# Saving timeLine: seq oral oral - oral genital ( 83 events )
# Event seq oral oral - oral genital created. eventNameWithId = seq oral oral - oral genital idA:2 idB:3 idC:None idD:None loadEvent: False
# seq oral oral - oral genital idA:2 idB:3 idC:None idD:None
# Number of event:  53
# Mean length of event:  53.16981132075472
# first event frame:  8303
# Keep previous entry.
# Saving timeLine: seq oral oral - oral genital ( 53 events )
# Event seq oral oral - oral genital created. eventNameWithId = seq oral oral - oral genital idA:3 idB:1 idC:None idD:None loadEvent: False
# seq oral oral - oral genital idA:3 idB:1 idC:None idD:None
# Number of event:  60
# Mean length of event:  57.083333333333336
# first event frame:  46760
# Keep previous entry.
# Saving timeLine: seq oral oral - oral genital ( 60 events )
# Event seq oral oral - oral genital created. eventNameWithId = seq oral oral - oral genital idA:3 idB:2 idC:None idD:None loadEvent: False
# seq oral oral - oral genital idA:3 idB:2 idC:None idD:None
# Number of event:  65
# Mean length of event:  54.753846153846155
# first event frame:  8701
# Keep previous entry.
# Saving timeLine: seq oral oral - oral genital ( 65 events )
# seq oral geni - oral oral
# Event seq oral geni - oral oral created. eventNameWithId = seq oral geni - oral oral idA:1 idB:2 idC:None idD:None loadEvent: False
# seq oral geni - oral oral idA:1 idB:2 idC:None idD:None
# Number of event:  85
# Mean length of event:  72.21176470588236
# first event frame:  13170
# Keep previous entry.
# Saving timeLine: seq oral geni - oral oral ( 85 events )
# Event seq oral geni - oral oral created. eventNameWithId = seq oral geni - oral oral idA:1 idB:3 idC:None idD:None loadEvent: False
# seq oral geni - oral oral idA:1 idB:3 idC:None idD:None
# Number of event:  57
# Mean length of event:  59.40350877192982
# first event frame:  10011
# Keep previous entry.
# Saving timeLine: seq oral geni - oral oral ( 57 events )
# Event seq oral geni - oral oral created. eventNameWithId = seq oral geni - oral oral idA:2 idB:1 idC:None idD:None loadEvent: False
# seq oral geni - oral oral idA:2 idB:1 idC:None idD:None
# Number of event:  82
# Mean length of event:  63.5609756097561
# first event frame:  36234
# Keep previous entry.
# Saving timeLine: seq oral geni - oral oral ( 82 events )
# Event seq oral geni - oral oral created. eventNameWithId = seq oral geni - oral oral idA:2 idB:3 idC:None idD:None loadEvent: False
# seq oral geni - oral oral idA:2 idB:3 idC:None idD:None
# Number of event:  63
# Mean length of event:  53.82539682539682
# first event frame:  7865
# Keep previous entry.
# Saving timeLine: seq oral geni - oral oral ( 63 events )
# Event seq oral geni - oral oral created. eventNameWithId = seq oral geni - oral oral idA:3 idB:1 idC:None idD:None loadEvent: False
# seq oral geni - oral oral idA:3 idB:1 idC:None idD:None
# Number of event:  48
# Mean length of event:  63.104166666666664
# first event frame:  15843
# Keep previous entry.
# Saving timeLine: seq oral geni - oral oral ( 48 events )
# Event seq oral geni - oral oral created. eventNameWithId = seq oral geni - oral oral idA:3 idB:2 idC:None idD:None loadEvent: False
# seq oral geni - oral oral idA:3 idB:2 idC:None idD:None
# Number of event:  60
# Mean length of event:  53.733333333333334
# first event frame:  8021
# Keep previous entry.
# Saving timeLine: seq oral geni - oral oral ( 60 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Oral Side Sequence','0','2020-03-26 17:21:23','0','332427' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventOralSideSequence' from '..\\lmtanalysis\\BuildEventOralSideSequence.py'>  ]  32.15751600265503  seconds
# [NEST 3] : Assume that there is no occlusion, does not work with anonymous animals
# [NEST3 Cancelled] 4 animals are required to build nest3.
# [Chrono  <module 'lmtanalysis.BuildEventNest3' from '..\\lmtanalysis\\BuildEventNest3.py'>  ]  0.001035928726196289  seconds
# [NEST 4] : Assume that there is no occlusion
# [NEST4 Cancelled] 4 animals are required to build nest 4.
# [Chrono  <module 'lmtanalysis.BuildEventNest4' from '..\\lmtanalysis\\BuildEventNest4.py'>  ]  0.0  seconds
# [Chrono  File C:/Users/amyrh/Documents/AA_Neuroscience_MSc/AA_Project/Live Mouse Tracker/Processing Data/Project11_CorrectDetectionIdentityGraphs/Novel Object/19666-01-03-05_06-02-2020_Obj_Rebuilt_Uncorrected.sqlite currentMinT: 0 currentMaxT: 332427  ]  4085.0572373867035  seconds
# Full file process time:
# [Chrono  File C:/Users/amyrh/Documents/AA_Neuroscience_MSc/AA_Project/Live Mouse Tracker/Processing Data/Project11_CorrectDetectionIdentityGraphs/Novel Object/19666-01-03-05_06-02-2020_Obj_Rebuilt_Uncorrected.sqlite  ]  4090.5415024757385  seconds
# [Chrono  Full batch  ]  4090.8925671577454  seconds
# *** ALL JOBS DONE ***
