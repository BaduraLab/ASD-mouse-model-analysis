# %% [markdown]
# # LMT analysis script for Amy and Lucas' data; Day: Wheel
#
# @author: Amy Hassett (ft. Fabrice/ Elodie's code)
#
# The purpose of this notebook is to act as the pipeline document for analysis of the LMT data, including any manipulations that must be performed before extracting the final data from the .sql database
#
#
# **Steps:**
# 1. Set up the environment > import things into the code that will be used later
# 2. Set genotype/ group identity > change the genotype or group identity of the animals (can also be done directly in the SQL file)
# 3. Check experiment reliability
# 4. Rebuild all events > Rebuild the database to include all the events that the LMT can compute. (i.e. the ones that are not computed in real-time; Note: this includes "CorrectDetectionIdentity").
# 5. Check experiment reliability (post fixing up)
# 6. Show sensor data (shows the data recorded by the arduino, located outside of the LMT enclosure, but inside the behavioural box)
# 7. Compute bad orientation estimation > This is a piece of code written by Fabrice, but it has not yet been full explored. We compute it just to have it.

# %% [markdown]
# ## Step 1: Performs the imports:
#
# **Note that the window that pops up to get the sql file may be hidden by other windows.**

# %%
'''
Created on 15 fev. 2019

@author: Fab
'''
# %matplotlib inline

import sys
sys.path.insert(1, "/mnt/Data1/LMT_Analysis/lmt-analysis-master/LMT")


import pandas as pd
import numpy as np

import sqlite3
from lmtanalysis.FileUtil import getFilesToProcess

from lmtanalysis.Animal import AnimalPool
from lmtanalysis.Measure import *
from lmtanalysis.Event import EventTimeLine, plotMultipleTimeLine

from lmtanalysis.Animal import *
import matplotlib.pyplot as plt
from lmtanalysis.Event import *
from lmtanalysis.Measure import *
import colorsys
from collections import Counter
import seaborn as sns

from tkinter.filedialog import askopenfilename
from lmtanalysis.Util import getMinTMaxTAndFileNameInput
from lmtanalysis.EventTimeLineCache import EventTimeLineCached
from lmtanalysis.FileUtil import getFilesToProcess

# %%
#ask the user for database to process
print( "Select file name in window")
files = getFilesToProcess()
# Out:
# Select file name in window

# %% [markdown]
# # Step 2: Set Genotype
# This code lets you set the genotype of each animal in your database.
#
# **Note that the text box will appear in the white area underneath this code!**

# %%
for file in files:
    
    print("---------------")
    print("Current file: " , file )
    
    connection = sqlite3.connect( file )
    
    pool = AnimalPool( )
    pool.loadAnimals( connection )
    
    for animal in pool.getAnimalList():
        print( "****")
        
        genotype = input( "Type new genotype for RFID "+ str(animal.RFID)+ " Current Genotype: " + str(animal.genotype) + " ([Enter] to keep existing one):")
        genotype = genotype.strip()
        if len(genotype) > 0:
            print("setting ", genotype , " to " , animal.RFID )
            animal.setGenotype( genotype )
        else:
            print( "keeping genotype", animal.genotype )
        
        name = input( "Type new name for RFID "+ str(animal.RFID)+ " Current Name: " + str(animal.name) + " ([Enter] to keep existing one):")
        name = name.strip()
        if len(name) > 0:
            print("setting ", name , " to " , animal.RFID )
            animal.setAnimalName( name )
        else:
            print( "keeping name", animal.name )
            
    print("Genotype saved in database.")
# Out:
# ---------------
# Current file:  C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004809816 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004809824 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004809810 Genotype:None User1:None
# ****
# Type new genotype for RFID 000004809816 Current Genotype: None ([Enter] to keep existing one):Shank2_WT
# setting  Shank2_WT  to  000004809816
# Type new name for RFID 000004809816 Current Name: A ([Enter] to keep existing one):M0020
# setting  M0020  to  000004809816
# ****
# Type new genotype for RFID 000004809824 Current Genotype: None ([Enter] to keep existing one):Shank2_WT
# setting  Shank2_WT  to  000004809824
# Type new name for RFID 000004809824 Current Name: B ([Enter] to keep existing one):M0022
# setting  M0022  to  000004809824
# ****
# Type new genotype for RFID 000004809810 Current Genotype: None ([Enter] to keep existing one):Shank2_KO
# setting  Shank2_KO  to  000004809810
# Type new name for RFID 000004809810 Current Name: C ([Enter] to keep existing one):M0021
# setting  M0021  to  000004809810
# Genotype saved in database.

# %% [markdown]
# # Step 3: Check experiment reliability (before processing)
# this code gives feedback on how well the experiment does and saves the results as a txt file. In particular it describes how much of the detection was correctly detected
#
# This code is repeated 5x below so that we can get the following data:
# 1. Missed detections (all of experiment)
# 2. Missed detections (hr1)
# 3. Missed detections (hr2)
# 4. Missed detections (hr3)
# 5. Missed detections (hr1 + hr2; combined)
#
# **Note: when naming the TXT file, ensure that it includes "_preprocessing" in the title**

# %%
def reliabilitycheck(Files,text_file,startFrame=None,endFrame=None):
    for file in files:
        ## Txt file of entire experiment
        print( file )
        connection = sqlite3.connect( file )
        c = connection.cursor()
        text_file.write( file )
        text_file.write("\n")
        
        ##########################################################################
        '''Compute total recording duration'''
        print ("##############################################################")
        query = "SELECT MIN(TIMESTAMP) FROM FRAME";
        c.execute( query )
        rows = c.fetchall()
        for row in rows:
            realStartTime = datetime.datetime.fromtimestamp(row[0]/1000)
            realStartInSeconds = row[0]/1000
        
        #return realStartTime
        print( "Time of experiment start: {}".format(realStartTime) )
        text_file.write ( "Time of experiment start: {}\n".format(realStartTime) )
        
        query = "SELECT MAX(TIMESTAMP) FROM FRAME";
        c.execute( query )
        rows = c.fetchall()
        for row in rows:
            realEndTime = datetime.datetime.fromtimestamp(row[0]/1000)
            realEndInSeconds = row[0]/1000
        
        #return realEndTime
        print( "Time of experiment end: {}".format(realEndTime) )
        text_file.write( "Time of experiment end: {}\n".format(realEndTime) )
        #Total duration of experiment based on timestamp
        realDurationInSeconds = realEndInSeconds - realStartInSeconds + 1
        print( "Real duration of experiment: {} s ({} frames)".format( realDurationInSeconds, realDurationInSeconds*30 ) )
        text_file.write( "Real duration of experiment: {} s ({} frames)\n".format( realDurationInSeconds, realDurationInSeconds*30 ) )
        
        ##########################################################################
        '''Compute the total number of frames recorded'''
        #nbFramesRecorded = getNumberOfFrames(file)
        print ("##############################################################")
        query = "SELECT * FROM FRAME";
        c.execute( query )
        framesRecorded = c.fetchall()
        nbFramesRecorded = len(framesRecorded)
        print ( "Number of frames recorded:  {} frames ({} seconds or {} minutes or {} hours or {} days)".format(nbFramesRecorded, nbFramesRecorded/oneSecond, nbFramesRecorded/oneMinute, nbFramesRecorded/oneHour, nbFramesRecorded/oneDay))
        text_file.write( "Number of frames recorded:  {} frames ({} seconds or {} minutes or {} hours or {} days)\n".format(nbFramesRecorded, nbFramesRecorded/oneSecond, nbFramesRecorded/oneMinute, nbFramesRecorded/oneHour, nbFramesRecorded/oneDay) )
        
        query = "SELECT MIN(FRAMENUMBER) FROM FRAME";
        c.execute( query )
        minFrames = c.fetchall()
        if startFrame ==None:
            for minFrame in minFrames:
                startFrame = minFrame[0]
        
        query = "SELECT MAX(FRAMENUMBER) FROM FRAME";
        c.execute( query )
        maxFrames = c.fetchall()
        if endFrame==None:
            for maxFrame in maxFrames:
                endFrame = maxFrame[0]  
        
        durationExp = endFrame - startFrame +1
        print ("Experiment duration based on frames: {} frames".format(durationExp) ) 
        
        nbOmittedFrames = realDurationInSeconds*oneSecond - nbFramesRecorded
        print ( "Number of frames omitted: {} ({} % of the total experiment duration)".format (nbOmittedFrames, 100*nbOmittedFrames/(realDurationInSeconds*oneSecond)) )
        text_file.write( "Number of frames omitted: {} ({} % of the total experiment duration)\n".format (nbOmittedFrames, 100*nbOmittedFrames/(realDurationInSeconds*oneSecond)) )
        text_file.write("\n")
        
        print ("##############################################################")
        ##########################################################################
        '''Number of animals detected and rate of detection'''
        pool = AnimalPool( )
        pool.loadAnimals( connection )
        pool.loadDetection( start = 216000, end = endFrame, lightLoad=True)
        print ("##############################################################")
        
        for animal in pool.animalDictionary.keys():
            
            nbOfDetections = pool.animalDictionary[animal].getNumberOfDetection(tmin = startFrame, tmax = endFrame)

            missedDetection = 1-nbOfDetections/nbFramesRecorded
            
            print ( "Animal {}: {} missed detections over {} frames recorded ({} %)".format( pool.animalDictionary[animal].RFID, nbFramesRecorded-nbOfDetections, nbFramesRecorded, missedDetection*100 ) )
            text_file.write( "Animal {}: {} missed detections over {} frames recorded ({} %)\n".format( pool.animalDictionary[animal].RFID, nbFramesRecorded-nbOfDetections, nbFramesRecorded, missedDetection*100 ) )
            '''Note: The score can be low, if the animals are often huddled in the nest and not identified individually.'''
        
        ##########################################################################
        '''Number of RFID match'''
        print ("##############################################################")
        
        for animal in pool.animalDictionary.keys():
            rfidMatchTimeLine = EventTimeLine( connection, "RFID MATCH", idA = animal )
            rfidMismatchTimeLine = EventTimeLine( connection, "RFID MISMATCH", idA = animal )
            nbOfRfidMatch = rfidMatchTimeLine.getNumberOfEvent(minFrame=216000, maxFrame=endFrame)
            nbOfRfidMismatch = rfidMismatchTimeLine.getNumberOfEvent(minFrame=216000, maxFrame=endFrame)
            print( "Number of RFID match for animal {}: {} (rate: {} events/min)".format( pool.animalDictionary[animal].RFID, nbOfRfidMatch, nbOfRfidMatch/(durationExp*30*60) ) )
            print( "Number of RFID mismatch for animal {}: {} (rate: {} events/min)".format( pool.animalDictionary[animal].RFID, nbOfRfidMismatch, nbOfRfidMismatch/(durationExp*30*60) ) )
            text_file.write( "Number of RFID match for animal {}: {} (rate: {} events/min)\n".format( pool.animalDictionary[animal].RFID, nbOfRfidMatch, nbOfRfidMatch/(durationExp*30*60) ) )
            text_file.write( "Number of RFID mismatch for animal {}: {} (rate: {} events/min)\n".format( pool.animalDictionary[animal].RFID, nbOfRfidMismatch, nbOfRfidMismatch/(durationExp*30*60) ) )
            
        print ("##############################################################")
        ##########################################################################
        '''Check events'''
        text_file.write( "\n" )
        text_file.write("Total number of each event type:\n")
        for event in behaviouralEvents:
            eventTimeLine = EventTimeLine( connection, event )
            nbOfEvents = eventTimeLine.getNumberOfEvent(minFrame=None, maxFrame=None)
            text_file.write("{}:\t {}\n".format(event, nbOfEvents))
        
        text_file.write( "\n" )    
        text_file.write( "##############################################################\n" )
        ##########################################################################
    text_file.write( "\n" )
    
    text_file.close()
    
    print("job done")

# %%
## Reliability checks

import sqlite3
import math
import time
import datetime
from lmtanalysis.Animal import *
import matplotlib.pyplot as plt
from lmtanalysis.Event import *
from lmtanalysis.Measure import *
import os
from tkinter.filedialog import askopenfilename
from lmtanalysis.Util import getMinTMaxTAndFileNameInput, getFileNameInput,\
    getNumberOfFrames
from lmtanalysis.FileUtil import getFilesToProcess

startFramelist=[None,None,108000,2160000,None]
endFramelist=[None,108000,2160000,None,2160000]
labels=["all","H1","H2","H3","H12"]

if __name__ == '__main__':
    '''This script allows to have an overview of the quality of the tracking for the whole experiment.'''
    
    behaviouralEvents = ["Contact", "Oral-oral Contact", "Oral-genital Contact", "Side by side Contact", "Side by side Contact, opposite way", "Social approach", "Social escape", "Approach contact", "Approach rear", "Break contact", "Get away", "FollowZone Isolated", "Train2", "Group2", "Group3", "Group 3 break", "Group 3 make", "Group4", "Group 4 break", "Group 4 make", "Huddling", "Move isolated", "Move in contact", "Nest3", "Nest4", "Rearing", "Rear isolated", "Rear in contact", "Stop isolated", "WallJump", "Wheel Zone"]
    ## Change these according to the behavioural day
    for i in range(len(startFramelist)):
        message="checking reliability before processing of time "+labels[i]+"\nReccomended to end the name with _preprocessing_"+labels[i]
        print(message)
        text_file = getFileNameInput()
        reliabilitycheck(files,text_file)
# Out:
# File name : 15441_uncorrected_obj_all
# C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite
# ##############################################################
# Time of experiment start: 2020-09-08 11:34:49.373000
# Time of experiment end: 2020-09-08 15:04:49.060000
# Real duration of experiment: 12600.68700003624 s (378020.6100010872 frames)
# ##############################################################
# Number of frames recorded:  376981 frames (12566.033333333333 seconds or 209.4338888888889 minutes or 3.4905648148148147 hours or 0.14544020061728394 days)
# Experiment duration based on frames: 376981 frames
# Number of frames omitted: 1039.6100010871887 (0.27501410599919374 % of the total experiment duration)
# ##############################################################
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=1 AND FRAMENUMBER<=376981
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None   196283  detections loaded in 1.1888253688812256 seconds.
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=1 AND FRAMENUMBER<=376981
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None   252634  detections loaded in 1.4575061798095703 seconds.
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=1 AND FRAMENUMBER<=376981
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None   238313  detections loaded in 1.3409936428070068 seconds.
# ##############################################################
# Animal 000004809810: 180698 missed detections over 376981 frames recorded (47.932919696218114 %)
# Animal 000004809816: 124347 missed detections over 376981 frames recorded (32.98495149622925 %)
# Animal 000004809824: 138668 missed detections over 376981 frames recorded (36.78381669102687 %)
# ##############################################################
# RFID MATCH  Id( 3 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 5358  records loaded in  0.21605157852172852 S )
# RFID MISMATCH  Id( 3 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 52  records loaded in  0.053012847900390625 S )
# Number of RFID match for animal 000004809810: 5358 (rate: 7.896065495785375e-06 events/min)
# Number of RFID mismatch for animal 000004809810: 52 (rate: 7.663221459142208e-08 events/min)
# RFID MATCH  Id( 1 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 18418  records loaded in  0.12302803993225098 S )
# RFID MISMATCH  Id( 1 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 49  records loaded in  0.0490117073059082 S )
# Number of RFID match for animal 000004809816: 18418 (rate: 2.7142540929707922e-05 events/min)
# Number of RFID mismatch for animal 000004809816: 49 (rate: 7.221112528807081e-08 events/min)
# RFID MATCH  Id( 2 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 11827  records loaded in  0.09702157974243164 S )
# RFID MISMATCH  Id( 2 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 44  records loaded in  0.05301260948181152 S )
# Number of RFID match for animal 000004809824: 11827 (rate: 1.742940773024517e-05 events/min)
# Number of RFID mismatch for animal 000004809824: 44 (rate: 6.484264311581869e-08 events/min)
# ##############################################################
# Contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 1717  records loaded in  0.12802886962890625 S )
# Oral-oral Contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 2753  records loaded in  0.07601809501647949 S )
# Oral-genital Contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 2889  records loaded in  0.07701706886291504 S )
# Side by side Contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 1469  records loaded in  0.06101417541503906 S )
# Side by side Contact, opposite way  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 15  records loaded in  0.052010297775268555 S )
# Social approach  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.048012733459472656 S )
# Social escape  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.047010183334350586 S )
# Approach contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.04701089859008789 S )
# Approach rear  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.04801034927368164 S )
# Break contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 1509  records loaded in  0.06301450729370117 S )
# Get away  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.048010826110839844 S )
# FollowZone Isolated  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.04601097106933594 S )
# Train2  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.17704010009765625 S )
# Group2  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.0580136775970459 S )
# Group3  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.04701089859008789 S )
# Group 3 break  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.04701113700866699 S )
# Group 3 make  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.1740398406982422 S )
# Group4  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.04701113700866699 S )
# Group 4 break  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.05201268196105957 S )
# Group 4 make  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.1490342617034912 S )
# Huddling  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.16403865814208984 S )
# Move isolated  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.047011375427246094 S )
# Move in contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.04701089859008789 S )
# Nest3  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.047011375427246094 S )
# Nest4  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.04701089859008789 S )
# Rearing  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 543  records loaded in  0.1870434284210205 S )
# Rear isolated  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.04901123046875 S )
# Rear in contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.16803884506225586 S )
# Stop isolated  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.17403912544250488 S )
# WallJump  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.18404173851013184 S )
# Wheel Zone  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.05301308631896973 S )
# job done

# %% [markdown]
# # Step 4:Rebuild All Events
#     This script builds/rebuilds all the events of Live Mouse Tracker
#
#    **Note: you need to make sure that you are using the notebook (and corresponding codes) that are correct for the particular experimental day that are you analysing.**
#
#    **Note: this code also includes "CorrectDetectionIdentity" enabled, which will remove Detections where all three mice are not visible in the frame.**
#
#
# ## Step 4.5(optional): Parameters:
#     This will compute automatically events for your database, and adjust settings for you.
#
#     If you remove the automatic settings, you can force parameters:
#         Set minT and maxT to process the database.
#         Set windowT to divide the computation load in segment of that duration. Default value is 1 day.

# %%
import sys
sys.path.insert(1, "../")
from lmtanalysis.Measure import *

# set this to false if you want to set manual parameters.
automaticSettings = True

# Manual parameters:

''' minT and maxT to process the analysis (expressed in frame) '''
minT = 0
maxT = 3*oneDay
''' time window to compute the events (in frame). '''
windowT = 1*oneDay
''' speed up process '''
USE_CACHE_LOAD_DETECTION_CACHE = True

# %% [markdown]
# ### Run this section to compute your database
#     You will be prompted to provide a database

# %%
##Optional, rechoose files to process for the plot
files = getFilesToProcess()

# %%
''' Created on 26 march 2019 @author: Fab '''

import sys
sys.path.insert(1, "../")
import sqlite3
from lmtanalysis.Animal import *
import matplotlib.pyplot as plt
from lmtanalysis.Event import *
from lmtanalysis.Measure import *
from lmtanalysis import BuildEventTrain3, BuildEventTrain4, BuildEventTrain2, BuildEventFollowZone, BuildEventRear5, BuildEventFloorSniffing,\
    BuildEventSocialApproach, BuildEventSocialEscape, BuildEventApproachContact,BuildEventOralOralContact,\
    BuildEventApproachRear, BuildEventGroup2, BuildEventGroup3, BuildEventGroup4, BuildEventOralGenitalContact, \
    BuildEventStop, BuildEventHuddling, \
    BuildEventMove, BuildEventGroup3MakeBreak, BuildEventGroup4MakeBreak,\
    BuildEventSideBySide, BuildEventSideBySideOpposite, BuildEventDetection,\
    BuildDataBaseIndex, BuildEventWallJump, BuildEventSAP,\
    BuildEventOralSideSequence, CheckWrongAnimal,BuildEventWheel,\
    CorrectDetectionIntegrity, BuildEventNest4, BuildEventNest3, BuildEventGetAway
    
from psutil import virtual_memory

from tkinter.filedialog import askopenfilename
from lmtanalysis.TaskLogger import TaskLogger
import sys
import traceback
from lmtanalysis.FileUtil import getFilesToProcess
from lmtanalysis.EventTimeLineCache import flushEventTimeLineCache,\
    disableEventTimeLineCache


from lmtanalysis.EventTimeLineCache import EventTimeLineCached

def getNumberOfFrames(file):
    
    connection = sqlite3.connect( file )
    c = connection.cursor() 
    query = "SELECT MAX(FRAMENUMBER) FROM FRAME";
    c.execute( query )
    result = c.fetchall()
    numberOfFrames = int( result[0][0] )
    connection.close()
    
    return numberOfFrames

class FileProcessException(Exception):
    pass

eventClassList = [                  
                  BuildEventOralOralContact,
                  BuildEventOralGenitalContact,
                  BuildEventSideBySide,
                  BuildEventSideBySideOpposite,
                  BuildEventTrain2,                  
                  BuildEventTrain3,
                  BuildEventTrain4,
                  BuildEventMove,
                  BuildEventFollowZone,
                  BuildEventRear5,
                  BuildEventSocialApproach,
                  BuildEventGetAway,
                  BuildEventSocialEscape,
                  BuildEventApproachRear,
                  BuildEventGroup2,
                  BuildEventGroup3,
                  BuildEventGroup4,
                  BuildEventGroup3MakeBreak,
                  BuildEventGroup4MakeBreak,
                  BuildEventStop,
                  BuildEventHuddling,
                  BuildEventApproachContact,
                  BuildEventWallJump,
                  BuildEventSAP,
                  BuildEventOralSideSequence,
                  BuildEventNest3,
                  BuildEventNest4,
                  BuildEventWheel
                   ]
def flushEvents( connection ):
    
    print("Flushing events...")

    for ev in eventClassList:
        
        chrono = Chronometer( "Flushing event " + str(ev) )
        ev.flush( connection );      
        chrono.printTimeInS()
    

def processTimeWindow( connection, currentMinT , currentMaxT ):
    
    CheckWrongAnimal.check( connection, tmin=currentMinT, tmax=currentMaxT )
    
    # Warning: enabling this process (CorrectDetectionIntegrity) will alter the database permanently
    CorrectDetectionIntegrity.correct( connection, tmin=0, tmax=maxT )
                            
    BuildEventDetection.reBuildEvent( connection, file, tmin=currentMinT, tmax=currentMaxT )

    animalPool = None
    
    flushEventTimeLineCache()
    
    if ( USE_CACHE_LOAD_DETECTION_CACHE ):
        print("Caching load of animal detection...")
        animalPool = AnimalPool( )
        animalPool.loadAnimals( connection )
        animalPool.loadDetection( start = currentMinT, end = currentMaxT )
        print("Caching load of animal detection done.")

    for ev in eventClassList:
        
        chrono = Chronometer( str( ev ) )
        ev.reBuildEvent( connection, file, tmin=currentMinT, tmax=currentMaxT, pool = animalPool )        
        chrono.printTimeInS()

def process( file ):

    print(file)
    
    if automaticSettings:
        print("Automatic settings.")
        windowT = 1*oneDay
        minT = 0
        maxT = getNumberOfFrames( file )
        print ( "Auto max set to" , maxT , "frames")
        
    
    chronoFullFile = Chronometer("File " + file )
    
    connection = sqlite3.connect( file )
    
    # update missing fields
    try:
        connection = sqlite3.connect( file )    
        c = connection.cursor()            
        query = "ALTER TABLE EVENT ADD METADATA TEXT";
        c.execute( query )    
        connection.commit()
        c.close()
        connection.close()
    except:
        print( "METADATA field already exists" , file )
        
    #build index
    
    BuildDataBaseIndex.buildDataBaseIndex( connection, force=False )
        
    '''
    # build sensor data    
    animalPool = AnimalPool( )
    animalPool.loadAnimals( connection )
    animalPool.buildSensorData(file)
    '''
    
    currentT = minT

    try:

        flushEvents( connection )
        
        while currentT < maxT:
                        
            currentMinT = currentT
            currentMaxT = currentT+ windowT
            if ( currentMaxT > maxT ):
                currentMaxT = maxT
                
            chronoTimeWindowFile = Chronometer("File "+ file+ " currentMinT: "+ str(currentMinT)+ " currentMaxT: " + str(currentMaxT) );
            processTimeWindow( connection, currentMinT, currentMaxT )    
            chronoTimeWindowFile.printTimeInS()
            
            currentT += windowT

                        

        print("Full file process time: ")
        chronoFullFile.printTimeInS()
        
        TEST_WINDOWING_COMPUTATION = False
        
        if ( TEST_WINDOWING_COMPUTATION ):
                
            print("*************")
            print("************* TEST START SECTION")
            print("************* Test if results are the same with or without the windowing.")
            
            # display and record to a file all events found, checking with rolling idA from None to 4. Save nbEvent and total len
            
            eventTimeLineList = []
            
            eventList = getAllEvents( connection )
            file = open("outEvent"+str(windowT)+".txt","w")  
            file.write( "Event name\nnb event\ntotal duration" )
            
            for eventName in eventList:
                for idAnimalA in range( 0,5 ):                
                        idA = idAnimalA 
                        if idA == 0:
                            idA = None
                        timeLine = EventTimeLineCached( connection, file, eventName, idA,  minFrame=minT, maxFrame=maxT )
                        eventTimeLineList.append( timeLine )
                        file.write( timeLine.eventNameWithId+"\t"+str(len(timeLine.eventList))+"\t"+str(timeLine.getTotalLength())+"\n" )            
            
            file.close() 
    
            #plotMultipleTimeLine( eventTimeLineList )
            
            print("************* END TEST")
        
        
    except:
        
        exc_type, exc_value, exc_traceback = sys.exc_info()
        lines = traceback.format_exception(exc_type, exc_value, exc_traceback)
        error = ''.join('!! ' + line for line in lines)
        
        t = TaskLogger( connection )
        t.addLog( error )
        
        print( error, file=sys.stderr ) 
        
        raise FileProcessException()
            
def getAllEvents( connection ):
    
    query = "select name from event group by name order by name"
    c = connection.cursor()     
    c.execute( query )    
    all_rows = c.fetchall()        
    header = [ "Name" ]
    data =[]    
    for row in all_rows:
        data.append( row[0] )
    return data        

print("Code launched.")

mem = virtual_memory()
availableMemoryGB = mem.total / 1000000000
print( "Total memory on computer: (GB)", availableMemoryGB ) 

if availableMemoryGB < 10:
    print( "Not enough memory to use cache load of events.")
    disableEventTimeLineCache()

print("A window is popping (maybe hidden) asking for files to process...")

chronoFullBatch = Chronometer("Full batch" )    

if ( files != None ):

    for file in files:
        try:
            print ( "Processing file" , file )
            process( file )
        except FileProcessException:
            print ( "STOP PROCESSING FILE " + file , file=sys.stderr  )

        flushEventTimeLineCache()

chronoFullBatch.printTimeInS()
print( "*** ALL JOBS DONE ***")
# Out:
# Code launched.
# Total memory on computer: (GB) 34.276663296
# A window is popping (maybe hidden) asking for files to process...
# Processing file C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite
# C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite
# Automatic settings.
# Auto max set to 376981 frames
# METADATA field already exists C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite
# Creating lmtanalysis indexes...
# CREATE INDEX `animalIndex` ON `ANIMAL` (`ID` );
# index animalIndex already exists
# CREATE INDEX `detectionIndex` ON `DETECTION` (`ID` ASC,`FRAMENUMBER` ASC);
# index detectionIndex already exists
# CREATE INDEX `detetIdIndex` ON `DETECTION` (`ID` ASC);
# index detetIdIndex already exists
# CREATE INDEX `detframenumberIndex` ON `DETECTION` (`FRAMENUMBER` ASC);
# index detframenumberIndex already exists
# CREATE INDEX `eventEndFrameIndex` ON `EVENT` (`ENDFRAME` ASC);
# index eventEndFrameIndex already exists
# CREATE INDEX `eventIndex` ON `EVENT` (`ID` ASC,`STARTFRAME` ASC,`ENDFRAME` ASC);
# index eventIndex already exists
# CREATE INDEX `eventStartFrameIndex` ON `EVENT` (`STARTFRAME` ASC);
# index eventStartFrameIndex already exists
# CREATE INDEX `eventstartendIndex` ON `EVENT` (`STARTFRAME` ASC,`ENDFRAME` ASC);
# index eventstartendIndex already exists
# CREATE INDEX `indexeventidIndex` ON `EVENT` (`ID` ASC);
# index indexeventidIndex already exists
# CREATE INDEX 'detectionFastLoadXYIndex' ON 'DETECTION' ('ANIMALID' ,'FRAMENUMBER' ASC,'MASS_X' ,'MASS_Y' );
# index detectionFastLoadXYIndex already exists
# Log table does not exists, creating Log table
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build DataBase Index','0','2020-10-06 19:35:51','0','-1' );
# Flushing events...
# Deleting event Oral-oral Contact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Oral-oral Contact"
# Number of event deleted: 6098
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventOralOralContact' from '..\\lmtanalysis\\BuildEventOralOralContact.py'>  ]  0.34099817276000977  seconds
# Deleting event Oral-genital Contact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Oral-genital Contact"
# Number of event deleted: 6074
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventOralGenitalContact' from '..\\lmtanalysis\\BuildEventOralGenitalContact.py'>  ]  0.36910343170166016  seconds
# Deleting event Side by side Contact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Side by side Contact"
# Number of event deleted: 3190
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventSideBySide' from '..\\lmtanalysis\\BuildEventSideBySide.py'>  ]  0.19185185432434082  seconds
# Deleting event Side by side Contact, opposite way (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Side by side Contact, opposite way"
# Number of event deleted: 30
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventSideBySideOpposite' from '..\\lmtanalysis\\BuildEventSideBySideOpposite.py'>  ]  0.058013200759887695  seconds
# Deleting event Train2 (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Train2"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventTrain2' from '..\\lmtanalysis\\BuildEventTrain2.py'>  ]  0.04701066017150879  seconds
# Deleting event Train3 (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Train3"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventTrain3' from '..\\lmtanalysis\\BuildEventTrain3.py'>  ]  0.04701089859008789  seconds
# Deleting event Train4 (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Train4"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventTrain4' from '..\\lmtanalysis\\BuildEventTrain4.py'>  ]  0.16103792190551758  seconds
# Deleting event Move (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Move"
# Number of event deleted: 0
# Deleting event Move isolated (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Move isolated"
# Number of event deleted: 0
# Deleting event Move in contact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Move in contact"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventMove' from '..\\lmtanalysis\\BuildEventMove.py'>  ]  0.13703107833862305  seconds
# Deleting event FollowZone Isolated (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="FollowZone Isolated"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventFollowZone' from '..\\lmtanalysis\\BuildEventFollowZone.py'>  ]  0.046010494232177734  seconds
# Deleting event Rear isolated (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Rear isolated"
# Number of event deleted: 0
# Deleting event Rear in contact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Rear in contact"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventRear5' from '..\\lmtanalysis\\BuildEventRear5.py'>  ]  0.0980222225189209  seconds
# Deleting event Social approach (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Social approach"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventSocialApproach' from '..\\lmtanalysis\\BuildEventSocialApproach.py'>  ]  0.04901123046875  seconds
# Deleting event Get away (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Get away"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventGetAway' from '..\\lmtanalysis\\BuildEventGetAway.py'>  ]  0.04501032829284668  seconds
# Deleting event Social escape (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Social escape"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventSocialEscape' from '..\\lmtanalysis\\BuildEventSocialEscape.py'>  ]  0.04601097106933594  seconds
# Deleting event Approach rear (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Approach rear"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventApproachRear' from '..\\lmtanalysis\\BuildEventApproachRear.py'>  ]  0.047009944915771484  seconds
# Deleting event Group2 (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Group2"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventGroup2' from '..\\lmtanalysis\\BuildEventGroup2.py'>  ]  0.046010494232177734  seconds
# Deleting event Group3 (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Group3"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventGroup3' from '..\\lmtanalysis\\BuildEventGroup3.py'>  ]  0.04501056671142578  seconds
# Deleting event Group4 (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Group4"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventGroup4' from '..\\lmtanalysis\\BuildEventGroup4.py'>  ]  0.04601025581359863  seconds
# Deleting event Group 3 make (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Group 3 make"
# Number of event deleted: 0
# Deleting event Group 3 break (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Group 3 break"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventGroup3MakeBreak' from '..\\lmtanalysis\\BuildEventGroup3MakeBreak.py'>  ]  0.09702277183532715  seconds
# Deleting event Group 4 make (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Group 4 make"
# Number of event deleted: 0
# Deleting event Group 4 break (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Group 4 break"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventGroup4MakeBreak' from '..\\lmtanalysis\\BuildEventGroup4MakeBreak.py'>  ]  0.09302115440368652  seconds
# Deleting event Stop in contact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Stop in contact"
# Number of event deleted: 0
# Deleting event Stop isolated (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Stop isolated"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventStop' from '..\\lmtanalysis\\BuildEventStop.py'>  ]  0.09302115440368652  seconds
# Deleting event Huddling (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Huddling"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventHuddling' from '..\\lmtanalysis\\BuildEventHuddling.py'>  ]  0.04601097106933594  seconds
# Deleting event Approach contact (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Approach contact"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventApproachContact' from '..\\lmtanalysis\\BuildEventApproachContact.py'>  ]  0.047010183334350586  seconds
# Deleting event WallJump (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="WallJump"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventWallJump' from '..\\lmtanalysis\\BuildEventWallJump.py'>  ]  0.049011945724487305  seconds
# Deleting event SAP (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="SAP"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventSAP' from '..\\lmtanalysis\\BuildEventSAP.py'>  ]  0.04601025581359863  seconds
# Deleting event seq oral oral - oral genital (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="seq oral oral - oral genital"
# Number of event deleted: 0
# Deleting event seq oral geni - oral oral (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="seq oral geni - oral oral"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventOralSideSequence' from '..\\lmtanalysis\\BuildEventOralSideSequence.py'>  ]  0.09202146530151367  seconds
# Deleting event Nest3_ (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Nest3_"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventNest3' from '..\\lmtanalysis\\BuildEventNest3.py'>  ]  0.0490107536315918  seconds
# Deleting event Nest4_ (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Nest4_"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventNest4' from '..\\lmtanalysis\\BuildEventNest4.py'>  ]  0.04601120948791504  seconds
# Deleting event Wheel Zone (idA:None,idB:None,idC:None,idD:None) from base...
# DELETE FROM EVENT WHERE NAME="Wheel Zone"
# Number of event deleted: 0
# [Chrono  Flushing event <module 'lmtanalysis.BuildEventWheel' from '..\\lmtanalysis\\BuildEventWheel.py'>  ]  0.04601025581359863  seconds
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# nb animals:  3
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Correct wrong animal','0','2020-10-06 19:35:54','0','376981' );
# Rebuild event finished.
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# Event IDs integrity ok created. eventNameWithId = IDs integrity ok idA:None idB:None idC:None idD:None loadEvent: False
# processing animal ID: 3
# SELECT FRAMENUMBER FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=7776000
#  detections loaded in 0.1960453987121582 seconds.
# processing animal ID: 1
# SELECT FRAMENUMBER FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=7776000
#  detections loaded in 0.24805808067321777 seconds.
# processing animal ID: 2
# SELECT FRAMENUMBER FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=7776000
#  detections loaded in 0.2340540885925293 seconds.
# Number of event:  1370
# Mean length of event:  100.18029197080293
# first event frame:  2
# Keep previous entry.
# Saving timeLine: IDs integrity ok ( 1370 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Correct detection integrity','0','2020-10-06 19:36:28','0','7776000' );
# Rebuild event finished.
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# Detection
# Event Detection created. eventNameWithId = Detection idA:1 idB:None idC:None idD:None loadEvent: False
# processing animal ID: 1
# SELECT FRAMENUMBER FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=376981
#  detections loaded in 0.13503170013427734 seconds.
# Number of event:  1370
# Mean length of event:  100.18029197080293
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Detection ( 1370 events )
# Detection
# Event Detection created. eventNameWithId = Detection idA:2 idB:None idC:None idD:None loadEvent: False
# processing animal ID: 2
# SELECT FRAMENUMBER FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=376981
#  detections loaded in 0.1360316276550293 seconds.
# Number of event:  1370
# Mean length of event:  100.18029197080293
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Detection ( 1370 events )
# Detection
# Event Detection created. eventNameWithId = Detection idA:3 idB:None idC:None idD:None loadEvent: False
# processing animal ID: 3
# SELECT FRAMENUMBER FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=376981
#  detections loaded in 0.14403247833251953 seconds.
# Number of event:  1370
# Mean length of event:  100.18029197080293
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Detection ( 1370 events )
# Detection
# Event Detection created. eventNameWithId = Detection idA:4 idB:None idC:None idD:None loadEvent: False
# processing animal ID: 4
# SELECT FRAMENUMBER FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=376981
#  detections loaded in 0.0 seconds.
# no event
# Keep previous entry.
# Saving timeLine: Detection ( 0 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Detection','0','2020-10-06 19:36:29','0','376981' );
# Rebuild event finished.
# Caching load of animal detection...
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=376981
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None   137246  detections loaded in 3.4528892040252686 seconds.
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=376981
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None   137245  detections loaded in 3.443432569503784 seconds.
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=376981
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None   137247  detections loaded in 3.5662736892700195 seconds.
# Caching load of animal detection done.
# Oral-oral Contact
# Event Oral-oral Contact created. eventNameWithId = Oral-oral Contact idA:1 idB:2 idC:None idD:None loadEvent: False
# Number of event:  727
# Mean length of event:  4.785419532324622
# first event frame:  204
# Keep previous entry.
# Saving timeLine: Oral-oral Contact ( 727 events )
# Oral-oral Contact
# Event Oral-oral Contact created. eventNameWithId = Oral-oral Contact idA:1 idB:3 idC:None idD:None loadEvent: False
# Number of event:  992
# Mean length of event:  4.818548387096774
# first event frame:  3656
# Keep previous entry.
# Saving timeLine: Oral-oral Contact ( 992 events )
# Oral-oral Contact
# Event Oral-oral Contact created. eventNameWithId = Oral-oral Contact idA:2 idB:1 idC:None idD:None loadEvent: False
# Number of event:  727
# Mean length of event:  4.785419532324622
# first event frame:  204
# Keep previous entry.
# Saving timeLine: Oral-oral Contact ( 727 events )
# Oral-oral Contact
# Event Oral-oral Contact created. eventNameWithId = Oral-oral Contact idA:2 idB:3 idC:None idD:None loadEvent: False
# Number of event:  843
# Mean length of event:  8.405693950177936
# first event frame:  5090
# Keep previous entry.
# Saving timeLine: Oral-oral Contact ( 843 events )
# Oral-oral Contact
# Event Oral-oral Contact created. eventNameWithId = Oral-oral Contact idA:3 idB:1 idC:None idD:None loadEvent: False
# Number of event:  992
# Mean length of event:  4.818548387096774
# first event frame:  3656
# Keep previous entry.
# Saving timeLine: Oral-oral Contact ( 992 events )
# Oral-oral Contact
# Event Oral-oral Contact created. eventNameWithId = Oral-oral Contact idA:3 idB:2 idC:None idD:None loadEvent: False
# Number of event:  843
# Mean length of event:  8.405693950177936
# first event frame:  5090
# Keep previous entry.
# Saving timeLine: Oral-oral Contact ( 843 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Oral Oral Contact','0','2020-10-06 19:36:41','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventOralOralContact' from '..\\lmtanalysis\\BuildEventOralOralContact.py'>  ]  1.2640290260314941  seconds
# Oral-genital Contact
# Event Oral-genital Contact created. eventNameWithId = Oral-genital Contact idA:1 idB:2 idC:None idD:None loadEvent: False
# Number of event:  402
# Mean length of event:  10.296019900497512
# first event frame:  180
# Keep previous entry.
# Saving timeLine: Oral-genital Contact ( 402 events )
# Oral-genital Contact
# Event Oral-genital Contact created. eventNameWithId = Oral-genital Contact idA:1 idB:3 idC:None idD:None loadEvent: False
# Number of event:  665
# Mean length of event:  11.798496240601503
# first event frame:  3659
# Keep previous entry.
# Saving timeLine: Oral-genital Contact ( 665 events )
# Oral-genital Contact
# Event Oral-genital Contact created. eventNameWithId = Oral-genital Contact idA:2 idB:1 idC:None idD:None loadEvent: False
# Number of event:  340
# Mean length of event:  11.361764705882353
# first event frame:  212
# Keep previous entry.
# Saving timeLine: Oral-genital Contact ( 340 events )
# Oral-genital Contact
# Event Oral-genital Contact created. eventNameWithId = Oral-genital Contact idA:2 idB:3 idC:None idD:None loadEvent: False
# Number of event:  439
# Mean length of event:  15.239179954441914
# first event frame:  4631
# Keep previous entry.
# Saving timeLine: Oral-genital Contact ( 439 events )
# Oral-genital Contact
# Event Oral-genital Contact created. eventNameWithId = Oral-genital Contact idA:3 idB:1 idC:None idD:None loadEvent: False
# Number of event:  538
# Mean length of event:  14.118959107806692
# first event frame:  3867
# Keep previous entry.
# Saving timeLine: Oral-genital Contact ( 538 events )
# Oral-genital Contact
# Event Oral-genital Contact created. eventNameWithId = Oral-genital Contact idA:3 idB:2 idC:None idD:None loadEvent: False
# Number of event:  478
# Mean length of event:  14.366108786610878
# first event frame:  5019
# Keep previous entry.
# Saving timeLine: Oral-genital Contact ( 478 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Oral Genital Contact','0','2020-10-06 19:36:43','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventOralGenitalContact' from '..\\lmtanalysis\\BuildEventOralGenitalContact.py'>  ]  1.4183154106140137  seconds
# Side by side Contact
# Event Side by side Contact created. eventNameWithId = Side by side Contact idA:1 idB:2 idC:None idD:None loadEvent: False
# Number of event:  426
# Mean length of event:  14.687793427230046
# first event frame:  206
# Keep previous entry.
# Saving timeLine: Side by side Contact ( 426 events )
# Side by side Contact
# Event Side by side Contact created. eventNameWithId = Side by side Contact idA:1 idB:3 idC:None idD:None loadEvent: False
# Number of event:  480
# Mean length of event:  19.575
# first event frame:  3944
# Keep previous entry.
# Saving timeLine: Side by side Contact ( 480 events )
# Side by side Contact
# Event Side by side Contact created. eventNameWithId = Side by side Contact idA:2 idB:1 idC:None idD:None loadEvent: False
# Number of event:  426
# Mean length of event:  14.687793427230046
# first event frame:  206
# Keep previous entry.
# Saving timeLine: Side by side Contact ( 426 events )
# Side by side Contact
# Event Side by side Contact created. eventNameWithId = Side by side Contact idA:2 idB:3 idC:None idD:None loadEvent: False
# Number of event:  430
# Mean length of event:  21.70232558139535
# first event frame:  6098
# Keep previous entry.
# Saving timeLine: Side by side Contact ( 430 events )
# Side by side Contact
# Event Side by side Contact created. eventNameWithId = Side by side Contact idA:3 idB:1 idC:None idD:None loadEvent: False
# Number of event:  480
# Mean length of event:  19.575
# first event frame:  3944
# Keep previous entry.
# Saving timeLine: Side by side Contact ( 480 events )
# Side by side Contact
# Event Side by side Contact created. eventNameWithId = Side by side Contact idA:3 idB:2 idC:None idD:None loadEvent: False
# Number of event:  430
# Mean length of event:  21.70232558139535
# first event frame:  6098
# Keep previous entry.
# Saving timeLine: Side by side Contact ( 430 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Side by side','0','2020-10-06 19:36:45','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventSideBySide' from '..\\lmtanalysis\\BuildEventSideBySide.py'>  ]  2.1741256713867188  seconds
# Side by side Contact, opposite way
# Event Side by side Contact, opposite way created. eventNameWithId = Side by side Contact, opposite way idA:1 idB:2 idC:None idD:None loadEvent: False
# Number of event:  356
# Mean length of event:  14.0561797752809
# first event frame:  211
# Keep previous entry.
# Saving timeLine: Side by side Contact, opposite way ( 356 events )
# Side by side Contact, opposite way
# Event Side by side Contact, opposite way created. eventNameWithId = Side by side Contact, opposite way idA:1 idB:3 idC:None idD:None loadEvent: False
# Number of event:  440
# Mean length of event:  22.179545454545455
# first event frame:  7108
# Keep previous entry.
# Saving timeLine: Side by side Contact, opposite way ( 440 events )
# Side by side Contact, opposite way
# Event Side by side Contact, opposite way created. eventNameWithId = Side by side Contact, opposite way idA:2 idB:1 idC:None idD:None loadEvent: False
# Number of event:  356
# Mean length of event:  14.0561797752809
# first event frame:  211
# Keep previous entry.
# Saving timeLine: Side by side Contact, opposite way ( 356 events )
# Side by side Contact, opposite way
# Event Side by side Contact, opposite way created. eventNameWithId = Side by side Contact, opposite way idA:2 idB:3 idC:None idD:None loadEvent: False
# Number of event:  387
# Mean length of event:  21.58656330749354
# first event frame:  4630
# Keep previous entry.
# Saving timeLine: Side by side Contact, opposite way ( 387 events )
# Side by side Contact, opposite way
# Event Side by side Contact, opposite way created. eventNameWithId = Side by side Contact, opposite way idA:3 idB:1 idC:None idD:None loadEvent: False
# Number of event:  440
# Mean length of event:  22.179545454545455
# first event frame:  7108
# Keep previous entry.
# Saving timeLine: Side by side Contact, opposite way ( 440 events )
# Side by side Contact, opposite way
# Event Side by side Contact, opposite way created. eventNameWithId = Side by side Contact, opposite way idA:3 idB:2 idC:None idD:None loadEvent: False
# Number of event:  387
# Mean length of event:  21.58656330749354
# first event frame:  4630
# Keep previous entry.
# Saving timeLine: Side by side Contact, opposite way ( 387 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Side by side opposite','0','2020-10-06 19:36:47','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventSideBySideOpposite' from '..\\lmtanalysis\\BuildEventSideBySideOpposite.py'>  ]  2.1259944438934326  seconds
# Oral-genital Contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 402  records loaded in  0.18304204940795898 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 665  records loaded in  0.18404245376586914 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 340  records loaded in  0.1870434284210205 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 439  records loaded in  0.18105483055114746 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 538  records loaded in  0.18602943420410156 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 478  records loaded in  0.18604350090026855 S )
# Caching eventTimeLine
# Train2
# Event Train2 created. eventNameWithId = Train2 idA:1 idB:2 idC:None idD:None loadEvent: False
# Number of event:  9
# Mean length of event:  7.333333333333333
# first event frame:  10952
# Keep previous entry.
# Saving timeLine: Train2 ( 9 events )
# Train2
# Event Train2 created. eventNameWithId = Train2 idA:1 idB:3 idC:None idD:None loadEvent: False
# Number of event:  4
# Mean length of event:  5.75
# first event frame:  12640
# Keep previous entry.
# Saving timeLine: Train2 ( 4 events )
# Train2
# Event Train2 created. eventNameWithId = Train2 idA:2 idB:1 idC:None idD:None loadEvent: False
# Number of event:  11
# Mean length of event:  6.2727272727272725
# first event frame:  31799
# Keep previous entry.
# Saving timeLine: Train2 ( 11 events )
# Train2
# Event Train2 created. eventNameWithId = Train2 idA:2 idB:3 idC:None idD:None loadEvent: False
# Number of event:  6
# Mean length of event:  6.166666666666667
# first event frame:  45350
# Keep previous entry.
# Saving timeLine: Train2 ( 6 events )
# Train2
# Event Train2 created. eventNameWithId = Train2 idA:3 idB:1 idC:None idD:None loadEvent: False
# Number of event:  11
# Mean length of event:  6.363636363636363
# first event frame:  4986
# Keep previous entry.
# Saving timeLine: Train2 ( 11 events )
# Train2
# Event Train2 created. eventNameWithId = Train2 idA:3 idB:2 idC:None idD:None loadEvent: False
# Number of event:  9
# Mean length of event:  6.666666666666667
# first event frame:  15307
# Keep previous entry.
# Saving timeLine: Train2 ( 9 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Train2','0','2020-10-06 19:36:48','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventTrain2' from '..\\lmtanalysis\\BuildEventTrain2.py'>  ]  1.4122703075408936  seconds
# Train2  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 9  records loaded in  0.1780412197113037 S )
# Caching eventTimeLine
# Train2  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 4  records loaded in  0.17904162406921387 S )
# Caching eventTimeLine
# Train2  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 0  records loaded in  0.17904138565063477 S )
# Caching eventTimeLine
# Train2  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 11  records loaded in  0.1760408878326416 S )
# Caching eventTimeLine
# Train2  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 6  records loaded in  0.18034934997558594 S )
# Caching eventTimeLine
# Train2  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 0  records loaded in  0.1830427646636963 S )
# Caching eventTimeLine
# Train2  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 11  records loaded in  0.1780407428741455 S )
# Caching eventTimeLine
# Train2  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 9  records loaded in  0.1760404109954834 S )
# Caching eventTimeLine
# Train2  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 0  records loaded in  0.1850428581237793 S )
# Caching eventTimeLine
# Train2  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 0  records loaded in  0.1760406494140625 S )
# Caching eventTimeLine
# Train2  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 0  records loaded in  0.17704105377197266 S )
# Caching eventTimeLine
# Train2  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 0  records loaded in  0.1760396957397461 S )
# Caching eventTimeLine
# Event Train3 created. eventNameWithId = Train3 idA:2 idB:3 idC:2 idD:None loadEvent: False
# Number of event:  1
# Mean length of event:  3.0
# first event frame:  348227
# Keep previous entry.
# Saving timeLine: Train3 ( 1 events )
# Event Train3 created. eventNameWithId = Train3 idA:3 idB:2 idC:3 idD:None loadEvent: False
# Number of event:  1
# Mean length of event:  3.0
# first event frame:  348227
# Keep previous entry.
# Saving timeLine: Train3 ( 1 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Train3','0','2020-10-06 19:36:50','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventTrain3' from '..\\lmtanalysis\\BuildEventTrain3.py'>  ]  2.1778035163879395  seconds
# Train2  Id( 1 , 2 , None , None ) Loaded from cache ( 9  records. )
# Train2  Id( 1 , 3 , None , None ) Loaded from cache ( 4  records. )
# Train2  Id( 2 , 1 , None , None ) Loaded from cache ( 11  records. )
# Train2  Id( 2 , 3 , None , None ) Loaded from cache ( 6  records. )
# Train2  Id( 3 , 1 , None , None ) Loaded from cache ( 11  records. )
# Train2  Id( 3 , 2 , None , None ) Loaded from cache ( 9  records. )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Train4','0','2020-10-06 19:36:50','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventTrain4' from '..\\lmtanalysis\\BuildEventTrain4.py'>  ]  0.008001327514648438  seconds
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# Stop  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 6338  records loaded in  0.3480796813964844 S )
# Detection  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 2679  records loaded in  0.3260762691497803 S )
# Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 1209  records loaded in  0.2230510711669922 S )
# Caching eventTimeLine
# Stop  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 11704  records loaded in  0.3610842227935791 S )
# Detection  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 7226  records loaded in  0.34007859230041504 S )
# Contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 1139  records loaded in  0.21104764938354492 S )
# Caching eventTimeLine
# Stop  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 6063  records loaded in  0.3470802307128906 S )
# Detection  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 2992  records loaded in  0.3054172992706299 S )
# Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 1346  records loaded in  0.22305083274841309 S )
# Caching eventTimeLine
# Event Move created. eventNameWithId = Move idA:1 idB:None idC:None idD:None loadEvent: False
# Number of event:  7152
# Mean length of event:  6.406180089485459
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Move ( 7152 events )
# Event Move isolated created. eventNameWithId = Move isolated idA:1 idB:None idC:None idD:None loadEvent: False
# Number of event:  6480
# Mean length of event:  5.819907407407407
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Move isolated ( 6480 events )
# Event Move in contact created. eventNameWithId = Move in contact idA:1 idB:None idC:None idD:None loadEvent: False
# Number of event:  1756
# Mean length of event:  4.61503416856492
# first event frame:  181
# Keep previous entry.
# Saving timeLine: Move in contact ( 1756 events )
# Event Move created. eventNameWithId = Move idA:2 idB:None idC:None idD:None loadEvent: False
# Number of event:  13510
# Mean length of event:  4.808512213175425
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Move ( 13510 events )
# Event Move isolated created. eventNameWithId = Move isolated idA:2 idB:None idC:None idD:None loadEvent: False
# Number of event:  13065
# Mean length of event:  4.369383849980865
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Move isolated ( 13065 events )
# Event Move in contact created. eventNameWithId = Move in contact idA:2 idB:None idC:None idD:None loadEvent: False
# Number of event:  1550
# Mean length of event:  5.081935483870968
# first event frame:  185
# Keep previous entry.
# Saving timeLine: Move in contact ( 1550 events )
# Event Move created. eventNameWithId = Move idA:3 idB:None idC:None idD:None loadEvent: False
# Number of event:  6789
# Mean length of event:  8.522757401679186
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Move ( 6789 events )
# Event Move isolated created. eventNameWithId = Move isolated idA:3 idB:None idC:None idD:None loadEvent: False
# Number of event:  6251
# Mean length of event:  7.705007198848184
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Move isolated ( 6251 events )
# Event Move in contact created. eventNameWithId = Move in contact idA:3 idB:None idC:None idD:None loadEvent: False
# Number of event:  2008
# Mean length of event:  4.8291832669322705
# first event frame:  1226
# Keep previous entry.
# Saving timeLine: Move in contact ( 2008 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Move','0','2020-10-06 19:36:58','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventMove' from '..\\lmtanalysis\\BuildEventMove.py'>  ]  7.250736236572266  seconds
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None
# mean animal bodysize:  36.35044273638442
# Contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 1756  records loaded in  0.2790651321411133 S )
# Caching eventTimeLine
# Contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 903  records loaded in  0.27906346321105957 S )
# Caching eventTimeLine
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None
# mean animal bodysize:  40.25365159866799
# Contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 1756  records loaded in  0.2790646553039551 S )
# Caching eventTimeLine
# Contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 668  records loaded in  0.27306222915649414 S )
# Caching eventTimeLine
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# mean animal bodysize:  44.1956067327822
# Contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 903  records loaded in  0.2700631618499756 S )
# Caching eventTimeLine
# Contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 668  records loaded in  0.2700622081756592 S )
# Caching eventTimeLine
# A follow B
# FollowZone Isolated
# Event FollowZone Isolated created. eventNameWithId = FollowZone Isolated idA:1 idB:3 idC:None idD:None loadEvent: False
# FollowZone Isolated idA:1 idB:3 idC:None idD:None
# Number of event:  400
# Mean length of event:  4.2925
# first event frame:  3933
# Keep previous entry.
# Saving timeLine: FollowZone Isolated ( 400 events )
# A follow B
# FollowZone Isolated
# Event FollowZone Isolated created. eventNameWithId = FollowZone Isolated idA:2 idB:3 idC:None idD:None loadEvent: False
# FollowZone Isolated idA:2 idB:3 idC:None idD:None
# Number of event:  262
# Mean length of event:  4.034351145038168
# first event frame:  3610
# Keep previous entry.
# Saving timeLine: FollowZone Isolated ( 262 events )
# A follow B
# FollowZone Isolated
# Event FollowZone Isolated created. eventNameWithId = FollowZone Isolated idA:3 idB:1 idC:None idD:None loadEvent: False
# FollowZone Isolated idA:3 idB:1 idC:None idD:None
# Number of event:  422
# Mean length of event:  4.672985781990521
# first event frame:  4979
# Keep previous entry.
# Saving timeLine: FollowZone Isolated ( 422 events )
# A follow B
# FollowZone Isolated
# Event FollowZone Isolated created. eventNameWithId = FollowZone Isolated idA:2 idB:1 idC:None idD:None loadEvent: False
# FollowZone Isolated idA:2 idB:1 idC:None idD:None
# Number of event:  238
# Mean length of event:  4.714285714285714
# first event frame:  208
# Keep previous entry.
# Saving timeLine: FollowZone Isolated ( 238 events )
# A follow B
# FollowZone Isolated
# Event FollowZone Isolated created. eventNameWithId = FollowZone Isolated idA:3 idB:2 idC:None idD:None loadEvent: False
# FollowZone Isolated idA:3 idB:2 idC:None idD:None
# Number of event:  281
# Mean length of event:  4.516014234875445
# first event frame:  3610
# Keep previous entry.
# Saving timeLine: FollowZone Isolated ( 281 events )
# A follow B
# FollowZone Isolated
# Event FollowZone Isolated created. eventNameWithId = FollowZone Isolated idA:1 idB:2 idC:None idD:None loadEvent: False
# FollowZone Isolated idA:1 idB:2 idC:None idD:None
# Number of event:  228
# Mean length of event:  5.092105263157895
# first event frame:  190
# Keep previous entry.
# Saving timeLine: FollowZone Isolated ( 228 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Follow Zone','0','2020-10-06 19:37:07','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventFollowZone' from '..\\lmtanalysis\\BuildEventFollowZone.py'>  ]  8.929730892181396  seconds
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None
# Contact  Id( 3 , None , None , None ) Loaded from cache ( 1346  records. )
# A rears
# Event Rear in contact created. eventNameWithId = Rear in contact idA:3 idB:None idC:None idD:None loadEvent: False
# Event Rear isolated created. eventNameWithId = Rear isolated idA:3 idB:None idC:None idD:None loadEvent: False
# Number of event:  859
# Mean length of event:  1.789289871944121
# first event frame:  4633
# Keep previous entry.
# Saving timeLine: Rear in contact ( 859 events )
# Number of event:  543
# Mean length of event:  2.911602209944751
# first event frame:  5037
# Keep previous entry.
# Saving timeLine: Rear isolated ( 543 events )
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None
# Contact  Id( 1 , None , None , None ) Loaded from cache ( 1209  records. )
# A rears
# Event Rear in contact created. eventNameWithId = Rear in contact idA:1 idB:None idC:None idD:None loadEvent: False
# Event Rear isolated created. eventNameWithId = Rear isolated idA:1 idB:None idC:None idD:None loadEvent: False
# Number of event:  1145
# Mean length of event:  2.0
# first event frame:  5139
# Keep previous entry.
# Saving timeLine: Rear in contact ( 1145 events )
# Number of event:  566
# Mean length of event:  2.9964664310954063
# first event frame:  484
# Keep previous entry.
# Saving timeLine: Rear isolated ( 566 events )
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# Contact  Id( 2 , None , None , None ) Loaded from cache ( 1139  records. )
# A rears
# Event Rear in contact created. eventNameWithId = Rear in contact idA:2 idB:None idC:None idD:None loadEvent: False
# Event Rear isolated created. eventNameWithId = Rear isolated idA:2 idB:None idC:None idD:None loadEvent: False
# Number of event:  797
# Mean length of event:  1.9058971141781682
# first event frame:  185
# Keep previous entry.
# Saving timeLine: Rear in contact ( 797 events )
# Number of event:  722
# Mean length of event:  3.419667590027701
# first event frame:  22
# Keep previous entry.
# Saving timeLine: Rear isolated ( 722 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Rear5','0','2020-10-06 19:37:07','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventRear5' from '..\\lmtanalysis\\BuildEventRear5.py'>  ]  0.8395359516143799  seconds
# Approach  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 9482  records loaded in  0.3170735836029053 S )
# Caching eventTimeLine
# Approach  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 9889  records loaded in  0.3210732936859131 S )
# Caching eventTimeLine
# Approach  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 10896  records loaded in  0.328075647354126 S )
# Caching eventTimeLine
# Approach  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 9398  records loaded in  0.32607436180114746 S )
# Caching eventTimeLine
# Approach  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 11626  records loaded in  0.3410792350769043 S )
# Caching eventTimeLine
# Approach  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 10114  records loaded in  0.32607507705688477 S )
# Caching eventTimeLine
# mean animal bodysize:  40.25359528311834
# mean animal bodysize:  44.1956342424772
# mean animal bodysize:  36.35044694256181
# Social approach
# Event Social approach created. eventNameWithId = Social approach idA:1 idB:2 idC:None idD:None loadEvent: False
# Number of event:  2457
# Mean length of event:  6.113553113553113
# first event frame:  173
# Keep previous entry.
# Saving timeLine: Social approach ( 2457 events )
# Social approach
# Event Social approach created. eventNameWithId = Social approach idA:1 idB:3 idC:None idD:None loadEvent: False
# Number of event:  2734
# Mean length of event:  5.698244330651061
# first event frame:  458
# Keep previous entry.
# Saving timeLine: Social approach ( 2734 events )
# Social approach
# Event Social approach created. eventNameWithId = Social approach idA:2 idB:1 idC:None idD:None loadEvent: False
# Number of event:  2385
# Mean length of event:  6.415932914046121
# first event frame:  200
# Keep previous entry.
# Saving timeLine: Social approach ( 2385 events )
# Social approach
# Event Social approach created. eventNameWithId = Social approach idA:2 idB:3 idC:None idD:None loadEvent: False
# Number of event:  2434
# Mean length of event:  6.16392769104355
# first event frame:  480
# Keep previous entry.
# Saving timeLine: Social approach ( 2434 events )
# Social approach
# Event Social approach created. eventNameWithId = Social approach idA:3 idB:1 idC:None idD:None loadEvent: False
# Number of event:  2973
# Mean length of event:  7.611167171207534
# first event frame:  827
# Keep previous entry.
# Saving timeLine: Social approach ( 2973 events )
# Social approach
# Event Social approach created. eventNameWithId = Social approach idA:3 idB:2 idC:None idD:None loadEvent: False
# Number of event:  2610
# Mean length of event:  6.504214559386973
# first event frame:  521
# Keep previous entry.
# Saving timeLine: Social approach ( 2610 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Social Approach','0','2020-10-06 19:37:12','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventSocialApproach' from '..\\lmtanalysis\\BuildEventSocialApproach.py'>  ]  4.8379833698272705  seconds
# Escape
# Get away
# Event Get away created. eventNameWithId = Get away idA:1 idB:2 idC:None idD:None loadEvent: False
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# Number of event:  4056
# Mean length of event:  6.027366863905326
# first event frame:  108
# Keep previous entry.
# Saving timeLine: Get away ( 4056 events )
# Get away
# Event Get away created. eventNameWithId = Get away idA:1 idB:3 idC:None idD:None loadEvent: False
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# Number of event:  3608
# Mean length of event:  5.909090909090909
# first event frame:  3
# Keep previous entry.
# Saving timeLine: Get away ( 3608 events )
# Get away
# Event Get away created. eventNameWithId = Get away idA:2 idB:1 idC:None idD:None loadEvent: False
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# Number of event:  4451
# Mean length of event:  6.283307121995057
# first event frame:  3
# Keep previous entry.
# Saving timeLine: Get away ( 4451 events )
# Get away
# Event Get away created. eventNameWithId = Get away idA:2 idB:3 idC:None idD:None loadEvent: False
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# Number of event:  4100
# Mean length of event:  6.085609756097561
# first event frame:  3
# Keep previous entry.
# Saving timeLine: Get away ( 4100 events )
# Get away
# Event Get away created. eventNameWithId = Get away idA:3 idB:1 idC:None idD:None loadEvent: False
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# WARNING: Detection.getDistanceTo : Distance Max reached. returning None
# ...
# current t 80000
# current t 90000
# current t 100000
# current t 110000
# current t 120000
# current t 130000
# current t 140000
# current t 150000
# current t 160000
# current t 170000
# current t 180000
# current t 190000
# current t 200000
# current t 210000
# current t 220000
# current t 230000
# current t 240000
# current t 250000
# current t 260000
# current t 270000
# current t 280000
# current t 290000
# current t 300000
# current t 310000
# current t 320000
# current t 330000
# Problem in Mask.getRoundness()
# Problem in Mask.getRoundness()
# current t 340000
# current t 350000
# current t 360000
# current t 370000
# Number of event:  736
# Mean length of event:  5.735054347826087
# first event frame:  2
# Keep previous entry.
# Saving timeLine: Huddling ( 736 events )
# Computing huddling for animal  Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# Event Huddling created. eventNameWithId = Huddling idA:2 idB:None idC:None idD:None loadEvent: False
# current t 0
# current t 10000
# current t 20000
# current t 30000
# current t 40000
# current t 50000
# current t 60000
# current t 70000
# current t 80000
# current t 90000
# current t 100000
# current t 110000
# current t 120000
# current t 130000
# current t 140000
# current t 150000
# current t 160000
# current t 170000
# current t 180000
# current t 190000
# current t 200000
# current t 210000
# current t 220000
# current t 230000
# current t 240000
# current t 250000
# current t 260000
# current t 270000
# current t 280000
# current t 290000
# current t 300000
# current t 310000
# current t 320000
# current t 330000
# current t 340000
# current t 350000
# current t 360000
# current t 370000
# Number of event:  617
# Mean length of event:  6.46839546191248
# first event frame:  2862
# Keep previous entry.
# Saving timeLine: Huddling ( 617 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Huddling','0','2020-10-06 19:55:14','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventHuddling' from '..\\lmtanalysis\\BuildEventHuddling.py'>  ]  1033.7831180095673  seconds
# Contact  Id( 1 , 2 , None , None ) Loaded from cache ( 668  records. )
# Social approach  Id( 1 , 2 , None , None ) Loaded from cache ( 2457  records. )
# Contact  Id( 1 , 3 , None , None ) Loaded from cache ( 1756  records. )
# Social approach  Id( 1 , 3 , None , None ) Loaded from cache ( 2734  records. )
# Contact  Id( 2 , 1 , None , None ) Loaded from cache ( 668  records. )
# Social approach  Id( 2 , 1 , None , None ) Loaded from cache ( 2385  records. )
# Contact  Id( 2 , 3 , None , None ) Loaded from cache ( 903  records. )
# Social approach  Id( 2 , 3 , None , None ) Loaded from cache ( 2434  records. )
# Contact  Id( 3 , 1 , None , None ) Loaded from cache ( 1756  records. )
# Social approach  Id( 3 , 1 , None , None ) Loaded from cache ( 2973  records. )
# Contact  Id( 3 , 2 , None , None ) Loaded from cache ( 903  records. )
# Social approach  Id( 3 , 2 , None , None ) Loaded from cache ( 2610  records. )
# Approach contact
# Event Approach contact created. eventNameWithId = Approach contact idA:1 idB:2 idC:None idD:None loadEvent: False
# Number of event:  2064
# Mean length of event:  6.030523255813954
# first event frame:  173
# Keep previous entry.
# Saving timeLine: Approach contact ( 2064 events )
# Approach contact
# Event Approach contact created. eventNameWithId = Approach contact idA:1 idB:3 idC:None idD:None loadEvent: False
# Number of event:  2484
# Mean length of event:  5.744766505636071
# first event frame:  2859
# Keep previous entry.
# Saving timeLine: Approach contact ( 2484 events )
# Approach contact
# Event Approach contact created. eventNameWithId = Approach contact idA:2 idB:1 idC:None idD:None loadEvent: False
# Number of event:  2092
# Mean length of event:  6.502390057361377
# first event frame:  200
# Keep previous entry.
# Saving timeLine: Approach contact ( 2092 events )
# Approach contact
# Event Approach contact created. eventNameWithId = Approach contact idA:2 idB:3 idC:None idD:None loadEvent: False
# Number of event:  2067
# Mean length of event:  6.261731978713111
# first event frame:  3045
# Keep previous entry.
# Saving timeLine: Approach contact ( 2067 events )
# Approach contact
# Event Approach contact created. eventNameWithId = Approach contact idA:3 idB:1 idC:None idD:None loadEvent: False
# Number of event:  2619
# Mean length of event:  7.649102710958381
# first event frame:  3668
# Keep previous entry.
# Saving timeLine: Approach contact ( 2619 events )
# Approach contact
# Event Approach contact created. eventNameWithId = Approach contact idA:3 idB:2 idC:None idD:None loadEvent: False
# Number of event:  2080
# Mean length of event:  6.576442307692307
# first event frame:  3606
# Keep previous entry.
# Saving timeLine: Approach contact ( 2080 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Approach Contact','0','2020-10-06 19:55:16','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventApproachContact' from '..\\lmtanalysis\\BuildEventApproachContact.py'>  ]  2.2395153045654297  seconds
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None
# A is jumping against the wall
# WallJump
# Event WallJump created. eventNameWithId = WallJump idA:3 idB:None idC:None idD:None loadEvent: False
# Number of event:  162
# Mean length of event:  2.493827160493827
# first event frame:  3986
# Keep previous entry.
# Saving timeLine: WallJump ( 162 events )
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None
# A is jumping against the wall
# WallJump
# Event WallJump created. eventNameWithId = WallJump idA:1 idB:None idC:None idD:None loadEvent: False
# Number of event:  201
# Mean length of event:  2.383084577114428
# first event frame:  3918
# Keep previous entry.
# Saving timeLine: WallJump ( 201 events )
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# A is jumping against the wall
# WallJump
# Event WallJump created. eventNameWithId = WallJump idA:2 idB:None idC:None idD:None loadEvent: False
# Number of event:  209
# Mean length of event:  2.4066985645933014
# first event frame:  2557
# Keep previous entry.
# Saving timeLine: WallJump ( 209 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Wall Jump','0','2020-10-06 19:55:22','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventWallJump' from '..\\lmtanalysis\\BuildEventWallJump.py'>  ]  5.453255891799927  seconds
# Event SAP created. eventNameWithId = SAP idA:3 idB:None idC:None idD:None loadEvent: False
# Number of event:  370
# Mean length of event:  4.589189189189189
# first event frame:  4994
# Keep previous entry.
# Saving timeLine: SAP ( 370 events )
# Event SAP created. eventNameWithId = SAP idA:1 idB:None idC:None idD:None loadEvent: False
# Number of event:  917
# Mean length of event:  3.7001090512540893
# first event frame:  1727
# Keep previous entry.
# Saving timeLine: SAP ( 917 events )
# Event SAP created. eventNameWithId = SAP idA:2 idB:None idC:None idD:None loadEvent: False
# Number of event:  697
# Mean length of event:  4.388809182209469
# first event frame:  389
# Keep previous entry.
# Saving timeLine: SAP ( 697 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event SAP','0','2020-10-06 19:55:24','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventSAP' from '..\\lmtanalysis\\BuildEventSAP.py'>  ]  1.7333993911743164  seconds
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None
# mean animal bodysize:  36.35044273638442
# Oral-oral Contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 992  records loaded in  0.42509984970092773 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 1 , 3 , None , None ) Loaded from cache ( 665  records. )
# Oral-oral Contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 843  records loaded in  0.4230978488922119 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 2 , 3 , None , None ) Loaded from cache ( 439  records. )
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None
# mean animal bodysize:  40.25365159866799
# Oral-oral Contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 992  records loaded in  0.42709803581237793 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 3 , 1 , None , None ) Loaded from cache ( 538  records. )
# Oral-oral Contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 727  records loaded in  0.4230976104736328 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 2 , 1 , None , None ) Loaded from cache ( 340  records. )
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# mean animal bodysize:  44.1956067327822
# Oral-oral Contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 843  records loaded in  0.4260978698730469 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 3 , 2 , None , None ) Loaded from cache ( 478  records. )
# Oral-oral Contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 376981 ) Loaded ( 727  records loaded in  0.4190959930419922 S )
# Caching eventTimeLine
# Oral-genital Contact  Id( 1 , 2 , None , None ) Loaded from cache ( 402  records. )
# seq oral oral - oral genital
# Event seq oral oral - oral genital created. eventNameWithId = seq oral oral - oral genital idA:1 idB:2 idC:None idD:None loadEvent: False
# seq oral oral - oral genital idA:1 idB:2 idC:None idD:None
# Number of event:  55
# Mean length of event:  63.4
# first event frame:  5416
# Keep previous entry.
# Saving timeLine: seq oral oral - oral genital ( 55 events )
# Event seq oral oral - oral genital created. eventNameWithId = seq oral oral - oral genital idA:1 idB:3 idC:None idD:None loadEvent: False
# seq oral oral - oral genital idA:1 idB:3 idC:None idD:None
# Number of event:  74
# Mean length of event:  72.62162162162163
# first event frame:  3656
# Keep previous entry.
# Saving timeLine: seq oral oral - oral genital ( 74 events )
# Event seq oral oral - oral genital created. eventNameWithId = seq oral oral - oral genital idA:2 idB:1 idC:None idD:None loadEvent: False
# seq oral oral - oral genital idA:2 idB:1 idC:None idD:None
# Number of event:  51
# Mean length of event:  59.76470588235294
# first event frame:  28806
# Keep previous entry.
# Saving timeLine: seq oral oral - oral genital ( 51 events )
# Event seq oral oral - oral genital created. eventNameWithId = seq oral oral - oral genital idA:2 idB:3 idC:None idD:None loadEvent: False
# seq oral oral - oral genital idA:2 idB:3 idC:None idD:None
# Number of event:  56
# Mean length of event:  70.07142857142857
# first event frame:  19774
# Keep previous entry.
# Saving timeLine: seq oral oral - oral genital ( 56 events )
# Event seq oral oral - oral genital created. eventNameWithId = seq oral oral - oral genital idA:3 idB:1 idC:None idD:None loadEvent: False
# seq oral oral - oral genital idA:3 idB:1 idC:None idD:None
# Number of event:  67
# Mean length of event:  70.44776119402985
# first event frame:  4986
# Keep previous entry.
# Saving timeLine: seq oral oral - oral genital ( 67 events )
# Event seq oral oral - oral genital created. eventNameWithId = seq oral oral - oral genital idA:3 idB:2 idC:None idD:None loadEvent: False
# seq oral oral - oral genital idA:3 idB:2 idC:None idD:None
# Number of event:  62
# Mean length of event:  73.58064516129032
# first event frame:  11004
# Keep previous entry.
# Saving timeLine: seq oral oral - oral genital ( 62 events )
# seq oral geni - oral oral
# Event seq oral geni - oral oral created. eventNameWithId = seq oral geni - oral oral idA:1 idB:2 idC:None idD:None loadEvent: False
# seq oral geni - oral oral idA:1 idB:2 idC:None idD:None
# Number of event:  17
# Mean length of event:  37.76470588235294
# first event frame:  12978
# Keep previous entry.
# Saving timeLine: seq oral geni - oral oral ( 17 events )
# Event seq oral geni - oral oral created. eventNameWithId = seq oral geni - oral oral idA:1 idB:3 idC:None idD:None loadEvent: False
# seq oral geni - oral oral idA:1 idB:3 idC:None idD:None
# Number of event:  36
# Mean length of event:  60.75
# first event frame:  6064
# Keep previous entry.
# Saving timeLine: seq oral geni - oral oral ( 36 events )
# Event seq oral geni - oral oral created. eventNameWithId = seq oral geni - oral oral idA:2 idB:1 idC:None idD:None loadEvent: False
# seq oral geni - oral oral idA:2 idB:1 idC:None idD:None
# Number of event:  17
# Mean length of event:  41.23529411764706
# first event frame:  12986
# Keep previous entry.
# Saving timeLine: seq oral geni - oral oral ( 17 events )
# Event seq oral geni - oral oral created. eventNameWithId = seq oral geni - oral oral idA:2 idB:3 idC:None idD:None loadEvent: False
# seq oral geni - oral oral idA:2 idB:3 idC:None idD:None
# Number of event:  31
# Mean length of event:  48.806451612903224
# first event frame:  13185
# Keep previous entry.
# Saving timeLine: seq oral geni - oral oral ( 31 events )
# Event seq oral geni - oral oral created. eventNameWithId = seq oral geni - oral oral idA:3 idB:1 idC:None idD:None loadEvent: False
# seq oral geni - oral oral idA:3 idB:1 idC:None idD:None
# Number of event:  30
# Mean length of event:  46.7
# first event frame:  7010
# Keep previous entry.
# Saving timeLine: seq oral geni - oral oral ( 30 events )
# Event seq oral geni - oral oral created. eventNameWithId = seq oral geni - oral oral idA:3 idB:2 idC:None idD:None loadEvent: False
# seq oral geni - oral oral idA:3 idB:2 idC:None idD:None
# Number of event:  24
# Mean length of event:  56.375
# first event frame:  44025
# Keep previous entry.
# Saving timeLine: seq oral geni - oral oral ( 24 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Oral Side Sequence','0','2020-10-06 19:55:28','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventOralSideSequence' from '..\\lmtanalysis\\BuildEventOralSideSequence.py'>  ]  4.472155809402466  seconds
# [NEST 3] : Assume that there is no occlusion, does not work with anonymous animals
# [NEST3 Cancelled] 4 animals are required to build nest3.
# [Chrono  <module 'lmtanalysis.BuildEventNest3' from '..\\lmtanalysis\\BuildEventNest3.py'>  ]  0.0  seconds
# [NEST 4] : Assume that there is no occlusion
# [NEST4 Cancelled] 4 animals are required to build nest 4.
# [Chrono  <module 'lmtanalysis.BuildEventNest4' from '..\\lmtanalysis\\BuildEventNest4.py'>  ]  0.0  seconds
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None
# A is in the zone around the wheel
# Wheel Zone
# Event Wheel Zone created. eventNameWithId = Wheel Zone idA:3 idB:None idC:None idD:None loadEvent: False
# Number of event:  648
# Mean length of event:  75.98765432098766
# first event frame:  1201
# Keep previous entry.
# Saving timeLine: Wheel Zone ( 648 events )
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None
# A is in the zone around the wheel
# Wheel Zone
# Event Wheel Zone created. eventNameWithId = Wheel Zone idA:1 idB:None idC:None idD:None loadEvent: False
# Number of event:  205
# Mean length of event:  227.82439024390243
# first event frame:  154
# Keep previous entry.
# Saving timeLine: Wheel Zone ( 205 events )
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# A is in the zone around the wheel
# Wheel Zone
# Event Wheel Zone created. eventNameWithId = Wheel Zone idA:2 idB:None idC:None idD:None loadEvent: False
# Number of event:  585
# Mean length of event:  105.54871794871795
# first event frame:  92
# Keep previous entry.
# Saving timeLine: Wheel Zone ( 585 events )
# INSERT INTO LOG( process,version,date,tmin,tmax) VALUES ( 'Build Event Wheel Point','0','2020-10-06 19:55:29','0','376981' );
# Rebuild event finished.
# [Chrono  <module 'lmtanalysis.BuildEventWheel' from '..\\lmtanalysis\\BuildEventWheel.py'>  ]  1.0038135051727295  seconds
# [Chrono  File C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite currentMinT: 0 currentMaxT: 376981  ]  1175.0744528770447  seconds
# Full file process time:
# [Chrono  File C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite  ]  1177.6237847805023  seconds
# [Chrono  Full batch  ]  1177.6747970581055  seconds
# *** ALL JOBS DONE ***

# %% [markdown]
# # Step 5: Check experiment reliability; post-correction
# this code gives feedback on how well the experiment does and saves the results as a txt file. In particular it describes how much of the detection was correctly detected
#
# **Note: when naming these TXT files, ensure that it includes "_postprocessing" in the title**

# %%
import sqlite3
import math
import time
import datetime
from lmtanalysis.Animal import *
import matplotlib.pyplot as plt
from lmtanalysis.Event import *
from lmtanalysis.Measure import *
import os
from tkinter.filedialog import askopenfilename
from lmtanalysis.Util import getMinTMaxTAndFileNameInput, getFileNameInput,\
    getNumberOfFrames
from lmtanalysis.FileUtil import getFilesToProcess

startFramelist=[None,None,108000,2160000,None]
endFramelist=[None,108000,2160000,None,2160000]
labels=["all","H1","H2","H3","H12"]

if __name__ == '__main__':
    '''This script allows to have an overview of the quality of the tracking for the whole experiment.'''
    
    behaviouralEvents = ["Contact", "Oral-oral Contact", "Oral-genital Contact", "Side by side Contact", "Side by side Contact, opposite way", "Social approach", "Social escape", "Approach contact", "Approach rear", "Break contact", "Get away", "FollowZone Isolated", "Train2", "Group2", "Group3", "Group 3 break", "Group 3 make", "Group4", "Group 4 break", "Group 4 make", "Huddling", "Move isolated", "Move in contact", "Nest3", "Nest4", "Rearing", "Rear isolated", "Rear in contact", "Stop isolated", "WallJump", "Wheel Zone"]
    ## Change these according to the behavioural day
    for i in range(len(startFramelist)):
        message="checking reliability after processing of time "+labels[i]+"\nReccomended to end the name with _preprocessing_"+labels[i]
        print(message)
        text_file = getFileNameInput()
        reliabilitycheck(files,text_file)

# %% [markdown]
# # Step 6: Show sensor data
#
# - This script plots the sensor data and saves them it in pdf figures.
# - Sensor supported : temperature, sound level, humidity, visible light, visible + infrared light.

# %%
##Optional, rechoose files to process for the plot
files = getFilesToProcess()

# %%
import sys
sys.path.insert(1, "../")

import sqlite3
from lmtanalysis.Animal import *
from lmtanalysis.Event import *
from lmtanalysis.Measure import *
from tkinter.filedialog import askopenfilename
import sys
from lmtanalysis.FileUtil import getFilesToProcess

class FileProcessException(Exception):
    pass

def process( file ):
    
    connection = sqlite3.connect( file )     

    print( "--------------")
    print( "Current file: ", file )
    
    connection = sqlite3.connect( file )
    # build sensor data
    animalPool = AnimalPool( )
    animalPool.loadAnimals( connection )
    animalPool.buildSensorData( file, show = True  )
    
print("Code launched.")


if ( files != None ):

    for file in files:
        try:
            print ( "Processing file" , file )
            process( file )
        except FileProcessException:
            print ( "STOP PROCESSING FILE " + file , file=sys.stderr  )

print( "*** ALL JOBS DONE ***")
# Out:
# Code launched.
# Processing file C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite
# --------------
# Current file:  C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# Build sensor data
# plotting sensor data.  TEMPERATURE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.0890204906463623 S )
# Saving figure : C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite_log_temperature.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  SOUND
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.0870211124420166 S )
# Saving figure : C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite_log_sound level.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  HUMIDITY
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.09002995491027832 S )
# Saving figure : C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite_log_humidity.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.08703327178955078 S )
# Saving figure : C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite_log_light visible.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLEANDIR
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  0.08803415298461914 S )
# Saving figure : C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite_log_light visible and infra.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# *** ALL JOBS DONE ***

# %% [markdown]
# # Step 7: Compute Bad Orientation Estimation
# Caveat: this only looks for events longer than 1 second
#
# **Note: after running this step, you must rename the resulting TXT file with the numbers of the mice used, as it automatically saves this as "bad orientation", and this will be written over the next time this code is run with the next processed database**

# %%
##Optional, rechoose files to process for the plot
files = getFilesToProcess()

# %%
'''
Created on 13 sept. 2017

@author: Fab
'''

import sqlite3
from lmtanalysis.Animal import *
import matplotlib.pyplot as plt
from lmtanalysis.Event import *
from lmtanalysis.Measure import *
from lmtanalysis import BuildEventTrain3, BuildEventTrain4, BuildEventTrain2, BuildEventFollowZone, BuildEventRear5, BuildEventFloorSniffing,\
    BuildEventSocialApproach, BuildEventSocialEscape, BuildEventApproachContact,BuildEventOralOralContact,\
    BuildEventApproachRear, BuildEventGroup2, BuildEventGroup3, BuildEventGroup4, BuildEventOralGenitalContact, \
    BuildEventStop, BuildEventWaterPoint, \
    BuildEventMove, BuildEventGroup3MakeBreak, BuildEventGroup4MakeBreak,\
    BuildEventSideBySide, BuildEventSideBySideOpposite, BuildEventDetection,\
    BuildDataBaseIndex, BuildEventWallJump, BuildEventSAP,\
    BuildEventOralSideSequence, CheckWrongAnimal,\
    CorrectDetectionIntegrity
    

from lmtanalysis.TaskLogger import TaskLogger
import sys
import traceback
from lmtanalysis.FileUtil import getFilesToProcess

maxT = 3*oneDay
### Change this based on your thresholding
SPEED_THRESHOLD_HIGH = NaN

class FileProcessException(Exception):
    pass

def getScalarProduct( a, b ):

    return a.x * b.x + a.y * b.y;

def isSameSign( a, b ):
    if ( a >= 0 and b >= 0 ):
         return True;
    if ( a < 0 and b < 0 ):
        return True;
    return False;


def process( file ):

    print(file)
    
    chronoFullFile = Chronometer("File " + file )
    
    connection = sqlite3.connect( file )        
        
                        
    try:

        animalPool = None
        
        print("Caching load of animal detection...")
        animalPool = AnimalPool( )
        animalPool.loadAnimals( connection )
        animalPool.loadDetection( start = 0, end = maxT )
        print("Caching load of animal detection done.")

        text_file = open ( "bad orientation.txt", "a")
  
        nb = {}
        totalLen = {}
  
        for animal in animalPool.getAnimalList():
            
            badOrientationTimeLine = EventTimeLine( None, "bad orientation auto" , animal.baseId , None , None , None , loadEvent=False )
            print ("Processing", animal )
            for t in range( 0, maxT ):
                
                orientation = animal.getOrientationVector( t )
                speedVector = animal.getSpeedVector( t )
                speed = animal.getSpeed( t )

                if ( orientation != None and speedVector != None and speed != None ):
                    if ( speed > SPEED_THRESHOLD_HIGH ):
                        
                        scalar = getScalarProduct( orientation , speedVector )
                        
                        if ( scalar > 0 ):
                            badOrientationTimeLine.addPunctualEvent( t )
           
            # we remove small durations event as we cannot be sure they are not artefact, so we keep only events longer than 1s
            badOrientationTimeLine.removeEventsBelowLength( 30 )
            print ( "Total len in frame: " , badOrientationTimeLine.getTotalLength( ) )
            totalLen[animal] = badOrientationTimeLine.getTotalLength( )
            nb[animal] = badOrientationTimeLine.getNbEvent()
            
            badOrientationTimeLine.endRebuildEventTimeLine(connection)

        text_file.write( "{}\t".format( file ) )
        for resKey in totalLen.keys():
            text_file.write( "animal\t{}\tnb\t{}\ttotalLen\t{}\t".format( animal.RFID , nb[resKey], totalLen[resKey] ) )     
        text_file.write( "\n" ) 
        text_file.close()

        chronoFullFile.printTimeInS()
        
    except:
        
        exc_type, exc_value, exc_traceback = sys.exc_info()
        lines = traceback.format_exception(exc_type, exc_value, exc_traceback)
        error = ''.join('!! ' + line for line in lines)
        
        t = TaskLogger( connection )
        t.addLog( error )
        
        print( error, file=sys.stderr ) 
        
        raise FileProcessException()
        

if __name__ == '__main__':
    
    print("Code launched.")
    

    chronoFullBatch = Chronometer("Full batch" )    
        
    if ( files != None ):
    
        for file in files:
            try:
                print ( "Processing file" , file )
                process( file )
            except FileProcessException:
                print ( "STOP PROCESSING FILE " + file , file=sys.stderr  )
    
    
    '''    
    for file in files:

        
        try:
            process( file )
        except FileProcessException:
            print ( "STOP PROCESSING FILE " + file , file=sys.stderr  )
        
    '''     
    chronoFullBatch.printTimeInS()
    print( "*** ALL JOBS DONE ***")
# Out:
# Code launched.
# Processing file C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite
# C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite
# Caching load of animal detection...
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=7776000
# Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None   137246  detections loaded in 1.5483696460723877 seconds.
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=7776000
# Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None   137245  detections loaded in 1.557358741760254 seconds.
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=7776000
# Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None   137247  detections loaded in 1.3993220329284668 seconds.
# Caching load of animal detection done.
# Event bad orientation auto created. eventNameWithId = bad orientation auto idA:3 idB:None idC:None idD:None loadEvent: False
# Processing Animal Id:3 Name:M0021 RFID:000004809810 Genotype:Shank2_KO User1:None
# Total len in frame:  0
# no event
# Keep previous entry.
# Saving timeLine: bad orientation auto ( 0 events )
# Event bad orientation auto created. eventNameWithId = bad orientation auto idA:1 idB:None idC:None idD:None loadEvent: False
# Processing Animal Id:1 Name:M0020 RFID:000004809816 Genotype:Shank2_WT User1:None
# Total len in frame:  0
# no event
# Keep previous entry.
# Saving timeLine: bad orientation auto ( 0 events )
# Event bad orientation auto created. eventNameWithId = bad orientation auto idA:2 idB:None idC:None idD:None loadEvent: False
# Processing Animal Id:2 Name:M0022 RFID:000004809824 Genotype:Shank2_WT User1:None
# Total len in frame:  0
# no event
# Keep previous entry.
# Saving timeLine: bad orientation auto ( 0 events )
# [Chrono  File C:/Users/amyhassett/Documents/LMT_Analysis/1-Behavioral_profiling_DATA/2. Python Processed Databases/15441-05-06-07_08-09-2020_Wheel.sqlite  ]  37.31268787384033  seconds
# [Chrono  Full batch  ]  37.44372081756592  seconds
# *** ALL JOBS DONE ***

# %% [markdown]
# # Done!
